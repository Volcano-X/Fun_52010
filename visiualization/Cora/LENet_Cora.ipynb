# %% [markdown]
# # Experiment on Cora dataset
#
# This notebook is to test Laplacian EigenNet on Cora dataset.

# %%
# import packages
import numpy as np
import scipy
from scipy.linalg import eigh
import scipy.sparse as sp
import scipy.io as io
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.preprocessing import normalize
from sklearn.manifold import TSNE, spectral_embedding
from sklearn.linear_model import LogisticRegression

import torch
import torch.nn as nn
import torch.nn.functional as F

import time
import os
from torch_geometric.datasets import Planetoid
from torch_geometric.utils import get_laplacian, remove_self_loops
import math

# %% [markdown]
# ## Read Data
#
# 1. X: original feature matrix
# 2. y: label
# 3. Z: hidden feature matrix
# 4. Y: learned graph representation matrix

# %%
dataset = Planetoid(root='../../data', name='cora')
data = dataset[0]
X = data.x
y = data.y

# %% [markdown]
# ## Define graph A and Laplacian L

# %%
class_num = 7
m, D = X.shape
edge_index, edge_weight = get_laplacian(data.edge_index, normalization='sym')
L_sym = torch.sparse.FloatTensor( edge_index, edge_weight, (m, m) )

edge_index, edge_weight = remove_self_loops( edge_index, -edge_weight )
A_sym = torch.sparse.FloatTensor( edge_index, edge_weight, (m, m) )

# %% [markdown]
# ## Laplacian EigenNet

# %% [markdown]
# ### Define the LENet model

# %%
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
class Encoder_linear(nn.Module):
    def __init__(self, n_feat, dim):
        super(Encoder_linear, self).__init__()
        self.W = nn.Parameter(torch.FloatTensor(n_feat, dim))
        self.bias = nn.Parameter(torch.empty(1, dim))
        self.n_feat = n_feat
        self.dim = dim
        self.reset_parameters()

    def reset_parameters(self):
        stdv = math.sqrt(3) / math.sqrt(self.n_feat)
        self.W.data.uniform_(-stdv, stdv)
        self.bias.data.uniform_(-stdv, stdv)

    def forward(self, X):
        X = F.dropout(X, training = self.training, p = 0.9)
        Z = torch.mm(X, self.W) + self.bias
        Z = F.normalize(Z)
        return Z

def LENet( Z, A, beta, K = 32):
    m, d = Z.shape
    alpha = m*(1-beta*0.95)/d
    # ! Propagate
    Y = Z
    Y_all = Y
    for _ in range(K):
        Y = beta * torch.spmm(A, Y)
        Y_all = Y_all + Y
    # ! Linear Transformation
    Y = Y_all
    U, s, _ = torch.linalg.svd( Z.T @ Y, full_matrices = True)
    s_inv_21 = 1 / torch.sqrt(s)
    W = ( U*s_inv_21 ) @ U.T
    Y = np.sqrt(alpha) * (Y @ W)
    return Y

def align_fun(Z, Y):
    return torch.mean( torch.sum( Z*Y, dim = 1 ) )

# %% [markdown]
# ### Start to train LENet

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

class Build_Data(Dataset):
    # Constructor
    def __init__(self, X):
        self.X = X
        self.len = self.X.shape[0]
    # Getting the data
    def __getitem__(self, index):
        return self.X[index], index
    # Getting length of the data
    def __len__(self):
        return self.len

# %%
beta = 0.9
dim_d = 16

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Encoder_linear(n_feat=D, dim=dim_d).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9, weight_decay=0, maximize = True)

A = A_sym.to(device)
X = X.to(device)
X_Data = Build_Data(X)
train_loader = DataLoader(X_Data, batch_size=512, shuffle=True, drop_last=False)

epoch = 0
align_epoch = []

for iter in range(520):
    if iter % 10 == 0:
        model.eval()
        with torch.no_grad():
            Z = model(X)
            Y = LENet( Z, A, beta, K = 32 )
    model.train()
    for X_batch, index in train_loader:
        optimizer.zero_grad()
        Z_batch = model(X_batch)
        align = align_fun(Z_batch, Y[index])
        align.backward()
        optimizer.step()
        # ! compute align value
        align_epoch.append(align.item())
        epoch = epoch + 1
        print(  'iter:{:04d}'.format(iter+1), 
                'epoch:{:04d}'.format(epoch), 
                '| align_epoch:{:.3f}'.format(align_epoch[-1]) )
# Out:
# iter:0001 epoch:0001 | align_epoch:0.184
# iter:0001 epoch:0002 | align_epoch:0.205
# iter:0001 epoch:0003 | align_epoch:0.198
# iter:0001 epoch:0004 | align_epoch:0.209
# iter:0001 epoch:0005 | align_epoch:0.197
# iter:0001 epoch:0006 | align_epoch:0.249
# iter:0002 epoch:0007 | align_epoch:0.222
# iter:0002 epoch:0008 | align_epoch:0.228
# iter:0002 epoch:0009 | align_epoch:0.224
# iter:0002 epoch:0010 | align_epoch:0.211
# iter:0002 epoch:0011 | align_epoch:0.233
# iter:0002 epoch:0012 | align_epoch:0.208
# iter:0003 epoch:0013 | align_epoch:0.243
# iter:0003 epoch:0014 | align_epoch:0.231
# iter:0003 epoch:0015 | align_epoch:0.252
# iter:0003 epoch:0016 | align_epoch:0.247
# iter:0003 epoch:0017 | align_epoch:0.251
# iter:0003 epoch:0018 | align_epoch:0.283
# iter:0004 epoch:0019 | align_epoch:0.242
# iter:0004 epoch:0020 | align_epoch:0.249
# iter:0004 epoch:0021 | align_epoch:0.265
# iter:0004 epoch:0022 | align_epoch:0.265
# iter:0004 epoch:0023 | align_epoch:0.255
# iter:0004 epoch:0024 | align_epoch:0.263
# iter:0005 epoch:0025 | align_epoch:0.263
# iter:0005 epoch:0026 | align_epoch:0.271
# iter:0005 epoch:0027 | align_epoch:0.280
# iter:0005 epoch:0028 | align_epoch:0.268
# iter:0005 epoch:0029 | align_epoch:0.282
# iter:0005 epoch:0030 | align_epoch:0.272
# iter:0006 epoch:0031 | align_epoch:0.279
# iter:0006 epoch:0032 | align_epoch:0.277
# iter:0006 epoch:0033 | align_epoch:0.282
# iter:0006 epoch:0034 | align_epoch:0.279
# iter:0006 epoch:0035 | align_epoch:0.281
# iter:0006 epoch:0036 | align_epoch:0.277
# iter:0007 epoch:0037 | align_epoch:0.294
# iter:0007 epoch:0038 | align_epoch:0.277
# iter:0007 epoch:0039 | align_epoch:0.297
# iter:0007 epoch:0040 | align_epoch:0.279
# iter:0007 epoch:0041 | align_epoch:0.291
# iter:0007 epoch:0042 | align_epoch:0.296
# iter:0008 epoch:0043 | align_epoch:0.298
# iter:0008 epoch:0044 | align_epoch:0.300
# iter:0008 epoch:0045 | align_epoch:0.296
# iter:0008 epoch:0046 | align_epoch:0.283
# iter:0008 epoch:0047 | align_epoch:0.291
# iter:0008 epoch:0048 | align_epoch:0.291
# iter:0009 epoch:0049 | align_epoch:0.291
# iter:0009 epoch:0050 | align_epoch:0.287
# iter:0009 epoch:0051 | align_epoch:0.292
# iter:0009 epoch:0052 | align_epoch:0.303
# iter:0009 epoch:0053 | align_epoch:0.289
# iter:0009 epoch:0054 | align_epoch:0.298
# iter:0010 epoch:0055 | align_epoch:0.304
# iter:0010 epoch:0056 | align_epoch:0.320
# iter:0010 epoch:0057 | align_epoch:0.302
# iter:0010 epoch:0058 | align_epoch:0.295
# iter:0010 epoch:0059 | align_epoch:0.305
# iter:0010 epoch:0060 | align_epoch:0.295
# iter:0011 epoch:0061 | align_epoch:0.319
# iter:0011 epoch:0062 | align_epoch:0.311
# iter:0011 epoch:0063 | align_epoch:0.325
# iter:0011 epoch:0064 | align_epoch:0.315
# iter:0011 epoch:0065 | align_epoch:0.322
# iter:0011 epoch:0066 | align_epoch:0.341
# iter:0012 epoch:0067 | align_epoch:0.332
# iter:0012 epoch:0068 | align_epoch:0.317
# iter:0012 epoch:0069 | align_epoch:0.316
# iter:0012 epoch:0070 | align_epoch:0.321
# iter:0012 epoch:0071 | align_epoch:0.320
# iter:0012 epoch:0072 | align_epoch:0.319
# iter:0013 epoch:0073 | align_epoch:0.310
# iter:0013 epoch:0074 | align_epoch:0.330
# iter:0013 epoch:0075 | align_epoch:0.315
# iter:0013 epoch:0076 | align_epoch:0.315
# iter:0013 epoch:0077 | align_epoch:0.340
# iter:0013 epoch:0078 | align_epoch:0.319
# iter:0014 epoch:0079 | align_epoch:0.324
# iter:0014 epoch:0080 | align_epoch:0.322
# iter:0014 epoch:0081 | align_epoch:0.320
# iter:0014 epoch:0082 | align_epoch:0.331
# iter:0014 epoch:0083 | align_epoch:0.341
# iter:0014 epoch:0084 | align_epoch:0.331
# iter:0015 epoch:0085 | align_epoch:0.323
# iter:0015 epoch:0086 | align_epoch:0.338
# iter:0015 epoch:0087 | align_epoch:0.337
# iter:0015 epoch:0088 | align_epoch:0.336
# iter:0015 epoch:0089 | align_epoch:0.326
# iter:0015 epoch:0090 | align_epoch:0.346
# iter:0016 epoch:0091 | align_epoch:0.320
# iter:0016 epoch:0092 | align_epoch:0.344
# iter:0016 epoch:0093 | align_epoch:0.314
# iter:0016 epoch:0094 | align_epoch:0.337
# iter:0016 epoch:0095 | align_epoch:0.338
# iter:0016 epoch:0096 | align_epoch:0.301
# iter:0017 epoch:0097 | align_epoch:0.326
# iter:0017 epoch:0098 | align_epoch:0.346
# iter:0017 epoch:0099 | align_epoch:0.337
# iter:0017 epoch:0100 | align_epoch:0.332
# iter:0017 epoch:0101 | align_epoch:0.332
# iter:0017 epoch:0102 | align_epoch:0.328
# iter:0018 epoch:0103 | align_epoch:0.347
# iter:0018 epoch:0104 | align_epoch:0.327
# iter:0018 epoch:0105 | align_epoch:0.347
# iter:0018 epoch:0106 | align_epoch:0.340
# iter:0018 epoch:0107 | align_epoch:0.332
# iter:0018 epoch:0108 | align_epoch:0.333
# iter:0019 epoch:0109 | align_epoch:0.331
# iter:0019 epoch:0110 | align_epoch:0.349
# iter:0019 epoch:0111 | align_epoch:0.333
# iter:0019 epoch:0112 | align_epoch:0.344
# iter:0019 epoch:0113 | align_epoch:0.347
# iter:0019 epoch:0114 | align_epoch:0.333
# iter:0020 epoch:0115 | align_epoch:0.339
# iter:0020 epoch:0116 | align_epoch:0.352
# iter:0020 epoch:0117 | align_epoch:0.332
# iter:0020 epoch:0118 | align_epoch:0.347
# iter:0020 epoch:0119 | align_epoch:0.345
# iter:0020 epoch:0120 | align_epoch:0.344
# iter:0021 epoch:0121 | align_epoch:0.343
# iter:0021 epoch:0122 | align_epoch:0.359
# iter:0021 epoch:0123 | align_epoch:0.356
# iter:0021 epoch:0124 | align_epoch:0.337
# iter:0021 epoch:0125 | align_epoch:0.347
# iter:0021 epoch:0126 | align_epoch:0.340
# iter:0022 epoch:0127 | align_epoch:0.361
# iter:0022 epoch:0128 | align_epoch:0.340
# iter:0022 epoch:0129 | align_epoch:0.359
# iter:0022 epoch:0130 | align_epoch:0.344
# iter:0022 epoch:0131 | align_epoch:0.332
# iter:0022 epoch:0132 | align_epoch:0.370
# iter:0023 epoch:0133 | align_epoch:0.328
# iter:0023 epoch:0134 | align_epoch:0.328
# iter:0023 epoch:0135 | align_epoch:0.362
# iter:0023 epoch:0136 | align_epoch:0.351
# iter:0023 epoch:0137 | align_epoch:0.354
# iter:0023 epoch:0138 | align_epoch:0.374
# iter:0024 epoch:0139 | align_epoch:0.356
# iter:0024 epoch:0140 | align_epoch:0.350
# iter:0024 epoch:0141 | align_epoch:0.350
# iter:0024 epoch:0142 | align_epoch:0.362
# iter:0024 epoch:0143 | align_epoch:0.347
# iter:0024 epoch:0144 | align_epoch:0.344
# iter:0025 epoch:0145 | align_epoch:0.349
# iter:0025 epoch:0146 | align_epoch:0.354
# iter:0025 epoch:0147 | align_epoch:0.355
# iter:0025 epoch:0148 | align_epoch:0.347
# iter:0025 epoch:0149 | align_epoch:0.350
# iter:0025 epoch:0150 | align_epoch:0.367
# iter:0026 epoch:0151 | align_epoch:0.353
# iter:0026 epoch:0152 | align_epoch:0.362
# iter:0026 epoch:0153 | align_epoch:0.359
# iter:0026 epoch:0154 | align_epoch:0.345
# iter:0026 epoch:0155 | align_epoch:0.357
# iter:0026 epoch:0156 | align_epoch:0.362
# iter:0027 epoch:0157 | align_epoch:0.354
# iter:0027 epoch:0158 | align_epoch:0.352
# iter:0027 epoch:0159 | align_epoch:0.366
# iter:0027 epoch:0160 | align_epoch:0.335
# iter:0027 epoch:0161 | align_epoch:0.358
# iter:0027 epoch:0162 | align_epoch:0.361
# iter:0028 epoch:0163 | align_epoch:0.365
# iter:0028 epoch:0164 | align_epoch:0.353
# iter:0028 epoch:0165 | align_epoch:0.358
# iter:0028 epoch:0166 | align_epoch:0.364
# iter:0028 epoch:0167 | align_epoch:0.353
# iter:0028 epoch:0168 | align_epoch:0.372
# iter:0029 epoch:0169 | align_epoch:0.352
# iter:0029 epoch:0170 | align_epoch:0.353
# iter:0029 epoch:0171 | align_epoch:0.366
# iter:0029 epoch:0172 | align_epoch:0.362
# iter:0029 epoch:0173 | align_epoch:0.350
# iter:0029 epoch:0174 | align_epoch:0.360
# iter:0030 epoch:0175 | align_epoch:0.355
# iter:0030 epoch:0176 | align_epoch:0.351
# iter:0030 epoch:0177 | align_epoch:0.352
# iter:0030 epoch:0178 | align_epoch:0.363
# iter:0030 epoch:0179 | align_epoch:0.363
# iter:0030 epoch:0180 | align_epoch:0.360
# iter:0031 epoch:0181 | align_epoch:0.366
# iter:0031 epoch:0182 | align_epoch:0.346
# iter:0031 epoch:0183 | align_epoch:0.373
# iter:0031 epoch:0184 | align_epoch:0.362
# iter:0031 epoch:0185 | align_epoch:0.355
# iter:0031 epoch:0186 | align_epoch:0.353
# iter:0032 epoch:0187 | align_epoch:0.355
# iter:0032 epoch:0188 | align_epoch:0.362
# iter:0032 epoch:0189 | align_epoch:0.347
# iter:0032 epoch:0190 | align_epoch:0.343
# iter:0032 epoch:0191 | align_epoch:0.376
# iter:0032 epoch:0192 | align_epoch:0.357
# iter:0033 epoch:0193 | align_epoch:0.366
# iter:0033 epoch:0194 | align_epoch:0.376
# iter:0033 epoch:0195 | align_epoch:0.372
# iter:0033 epoch:0196 | align_epoch:0.349
# iter:0033 epoch:0197 | align_epoch:0.348
# iter:0033 epoch:0198 | align_epoch:0.365
# iter:0034 epoch:0199 | align_epoch:0.371
# iter:0034 epoch:0200 | align_epoch:0.368
# iter:0034 epoch:0201 | align_epoch:0.361
# iter:0034 epoch:0202 | align_epoch:0.362
# iter:0034 epoch:0203 | align_epoch:0.366
# iter:0034 epoch:0204 | align_epoch:0.375
# iter:0035 epoch:0205 | align_epoch:0.389
# iter:0035 epoch:0206 | align_epoch:0.372
# iter:0035 epoch:0207 | align_epoch:0.365
# iter:0035 epoch:0208 | align_epoch:0.364
# iter:0035 epoch:0209 | align_epoch:0.373
# iter:0035 epoch:0210 | align_epoch:0.343
# iter:0036 epoch:0211 | align_epoch:0.368
# iter:0036 epoch:0212 | align_epoch:0.379
# iter:0036 epoch:0213 | align_epoch:0.348
# iter:0036 epoch:0214 | align_epoch:0.366
# iter:0036 epoch:0215 | align_epoch:0.374
# iter:0036 epoch:0216 | align_epoch:0.400
# iter:0037 epoch:0217 | align_epoch:0.373
# iter:0037 epoch:0218 | align_epoch:0.389
# iter:0037 epoch:0219 | align_epoch:0.356
# iter:0037 epoch:0220 | align_epoch:0.361
# iter:0037 epoch:0221 | align_epoch:0.389
# iter:0037 epoch:0222 | align_epoch:0.352
# iter:0038 epoch:0223 | align_epoch:0.368
# iter:0038 epoch:0224 | align_epoch:0.375
# iter:0038 epoch:0225 | align_epoch:0.359
# iter:0038 epoch:0226 | align_epoch:0.368
# iter:0038 epoch:0227 | align_epoch:0.363
# iter:0038 epoch:0228 | align_epoch:0.402
# iter:0039 epoch:0229 | align_epoch:0.375
# iter:0039 epoch:0230 | align_epoch:0.368
# iter:0039 epoch:0231 | align_epoch:0.356
# iter:0039 epoch:0232 | align_epoch:0.372
# iter:0039 epoch:0233 | align_epoch:0.367
# iter:0039 epoch:0234 | align_epoch:0.357
# iter:0040 epoch:0235 | align_epoch:0.376
# iter:0040 epoch:0236 | align_epoch:0.382
# iter:0040 epoch:0237 | align_epoch:0.374
# iter:0040 epoch:0238 | align_epoch:0.357
# iter:0040 epoch:0239 | align_epoch:0.380
# iter:0040 epoch:0240 | align_epoch:0.388
# iter:0041 epoch:0241 | align_epoch:0.368
# iter:0041 epoch:0242 | align_epoch:0.358
# iter:0041 epoch:0243 | align_epoch:0.395
# iter:0041 epoch:0244 | align_epoch:0.378
# iter:0041 epoch:0245 | align_epoch:0.374
# iter:0041 epoch:0246 | align_epoch:0.403
# iter:0042 epoch:0247 | align_epoch:0.366
# iter:0042 epoch:0248 | align_epoch:0.383
# iter:0042 epoch:0249 | align_epoch:0.388
# iter:0042 epoch:0250 | align_epoch:0.375
# iter:0042 epoch:0251 | align_epoch:0.361
# iter:0042 epoch:0252 | align_epoch:0.377
# iter:0043 epoch:0253 | align_epoch:0.365
# iter:0043 epoch:0254 | align_epoch:0.382
# iter:0043 epoch:0255 | align_epoch:0.383
# iter:0043 epoch:0256 | align_epoch:0.388
# iter:0043 epoch:0257 | align_epoch:0.384
# iter:0043 epoch:0258 | align_epoch:0.359
# iter:0044 epoch:0259 | align_epoch:0.380
# iter:0044 epoch:0260 | align_epoch:0.375
# iter:0044 epoch:0261 | align_epoch:0.371
# iter:0044 epoch:0262 | align_epoch:0.372
# iter:0044 epoch:0263 | align_epoch:0.374
# iter:0044 epoch:0264 | align_epoch:0.401
# iter:0045 epoch:0265 | align_epoch:0.388
# iter:0045 epoch:0266 | align_epoch:0.375
# iter:0045 epoch:0267 | align_epoch:0.386
# iter:0045 epoch:0268 | align_epoch:0.364
# iter:0045 epoch:0269 | align_epoch:0.375
# iter:0045 epoch:0270 | align_epoch:0.396
# iter:0046 epoch:0271 | align_epoch:0.371
# iter:0046 epoch:0272 | align_epoch:0.384
# iter:0046 epoch:0273 | align_epoch:0.375
# iter:0046 epoch:0274 | align_epoch:0.390
# iter:0046 epoch:0275 | align_epoch:0.378
# iter:0046 epoch:0276 | align_epoch:0.383
# iter:0047 epoch:0277 | align_epoch:0.380
# iter:0047 epoch:0278 | align_epoch:0.378
# iter:0047 epoch:0279 | align_epoch:0.369
# iter:0047 epoch:0280 | align_epoch:0.371
# iter:0047 epoch:0281 | align_epoch:0.376
# iter:0047 epoch:0282 | align_epoch:0.376
# iter:0048 epoch:0283 | align_epoch:0.394
# iter:0048 epoch:0284 | align_epoch:0.396
# iter:0048 epoch:0285 | align_epoch:0.380
# iter:0048 epoch:0286 | align_epoch:0.391
# iter:0048 epoch:0287 | align_epoch:0.383
# iter:0048 epoch:0288 | align_epoch:0.402
# iter:0049 epoch:0289 | align_epoch:0.371
# iter:0049 epoch:0290 | align_epoch:0.372
# iter:0049 epoch:0291 | align_epoch:0.394
# iter:0049 epoch:0292 | align_epoch:0.388
# iter:0049 epoch:0293 | align_epoch:0.399
# iter:0049 epoch:0294 | align_epoch:0.377
# iter:0050 epoch:0295 | align_epoch:0.395
# iter:0050 epoch:0296 | align_epoch:0.373
# iter:0050 epoch:0297 | align_epoch:0.381
# iter:0050 epoch:0298 | align_epoch:0.380
# iter:0050 epoch:0299 | align_epoch:0.387
# iter:0050 epoch:0300 | align_epoch:0.372
# iter:0051 epoch:0301 | align_epoch:0.412
# iter:0051 epoch:0302 | align_epoch:0.408
# iter:0051 epoch:0303 | align_epoch:0.375
# iter:0051 epoch:0304 | align_epoch:0.382
# iter:0051 epoch:0305 | align_epoch:0.374
# iter:0051 epoch:0306 | align_epoch:0.410
# iter:0052 epoch:0307 | align_epoch:0.380
# iter:0052 epoch:0308 | align_epoch:0.385
# iter:0052 epoch:0309 | align_epoch:0.394
# iter:0052 epoch:0310 | align_epoch:0.394
# iter:0052 epoch:0311 | align_epoch:0.381
# iter:0052 epoch:0312 | align_epoch:0.370
# iter:0053 epoch:0313 | align_epoch:0.388
# iter:0053 epoch:0314 | align_epoch:0.388
# iter:0053 epoch:0315 | align_epoch:0.398
# iter:0053 epoch:0316 | align_epoch:0.390
# iter:0053 epoch:0317 | align_epoch:0.392
# iter:0053 epoch:0318 | align_epoch:0.370
# iter:0054 epoch:0319 | align_epoch:0.394
# iter:0054 epoch:0320 | align_epoch:0.380
# iter:0054 epoch:0321 | align_epoch:0.381
# iter:0054 epoch:0322 | align_epoch:0.386
# iter:0054 epoch:0323 | align_epoch:0.397
# iter:0054 epoch:0324 | align_epoch:0.353
# iter:0055 epoch:0325 | align_epoch:0.390
# iter:0055 epoch:0326 | align_epoch:0.401
# iter:0055 epoch:0327 | align_epoch:0.394
# iter:0055 epoch:0328 | align_epoch:0.396
# iter:0055 epoch:0329 | align_epoch:0.383
# iter:0055 epoch:0330 | align_epoch:0.370
# iter:0056 epoch:0331 | align_epoch:0.383
# iter:0056 epoch:0332 | align_epoch:0.388
# iter:0056 epoch:0333 | align_epoch:0.416
# iter:0056 epoch:0334 | align_epoch:0.399
# iter:0056 epoch:0335 | align_epoch:0.372
# iter:0056 epoch:0336 | align_epoch:0.382
# iter:0057 epoch:0337 | align_epoch:0.397
# iter:0057 epoch:0338 | align_epoch:0.406
# iter:0057 epoch:0339 | align_epoch:0.389
# iter:0057 epoch:0340 | align_epoch:0.383
# iter:0057 epoch:0341 | align_epoch:0.391
# iter:0057 epoch:0342 | align_epoch:0.403
# iter:0058 epoch:0343 | align_epoch:0.404
# iter:0058 epoch:0344 | align_epoch:0.381
# iter:0058 epoch:0345 | align_epoch:0.379
# iter:0058 epoch:0346 | align_epoch:0.374
# iter:0058 epoch:0347 | align_epoch:0.405
# iter:0058 epoch:0348 | align_epoch:0.387
# iter:0059 epoch:0349 | align_epoch:0.421
# iter:0059 epoch:0350 | align_epoch:0.398
# iter:0059 epoch:0351 | align_epoch:0.381
# iter:0059 epoch:0352 | align_epoch:0.394
# iter:0059 epoch:0353 | align_epoch:0.386
# iter:0059 epoch:0354 | align_epoch:0.378
# iter:0060 epoch:0355 | align_epoch:0.408
# iter:0060 epoch:0356 | align_epoch:0.379
# iter:0060 epoch:0357 | align_epoch:0.393
# iter:0060 epoch:0358 | align_epoch:0.394
# iter:0060 epoch:0359 | align_epoch:0.403
# iter:0060 epoch:0360 | align_epoch:0.414
# iter:0061 epoch:0361 | align_epoch:0.409
# iter:0061 epoch:0362 | align_epoch:0.392
# iter:0061 epoch:0363 | align_epoch:0.416
# iter:0061 epoch:0364 | align_epoch:0.382
# iter:0061 epoch:0365 | align_epoch:0.387
# iter:0061 epoch:0366 | align_epoch:0.406
# iter:0062 epoch:0367 | align_epoch:0.408
# iter:0062 epoch:0368 | align_epoch:0.393
# iter:0062 epoch:0369 | align_epoch:0.386
# iter:0062 epoch:0370 | align_epoch:0.401
# iter:0062 epoch:0371 | align_epoch:0.395
# iter:0062 epoch:0372 | align_epoch:0.405
# iter:0063 epoch:0373 | align_epoch:0.379
# iter:0063 epoch:0374 | align_epoch:0.398
# iter:0063 epoch:0375 | align_epoch:0.390
# iter:0063 epoch:0376 | align_epoch:0.391
# iter:0063 epoch:0377 | align_epoch:0.394
# iter:0063 epoch:0378 | align_epoch:0.390
# iter:0064 epoch:0379 | align_epoch:0.421
# iter:0064 epoch:0380 | align_epoch:0.385
# iter:0064 epoch:0381 | align_epoch:0.386
# iter:0064 epoch:0382 | align_epoch:0.408
# iter:0064 epoch:0383 | align_epoch:0.412
# iter:0064 epoch:0384 | align_epoch:0.364
# iter:0065 epoch:0385 | align_epoch:0.418
# iter:0065 epoch:0386 | align_epoch:0.383
# iter:0065 epoch:0387 | align_epoch:0.389
# iter:0065 epoch:0388 | align_epoch:0.407
# iter:0065 epoch:0389 | align_epoch:0.408
# iter:0065 epoch:0390 | align_epoch:0.369
# iter:0066 epoch:0391 | align_epoch:0.406
# iter:0066 epoch:0392 | align_epoch:0.406
# iter:0066 epoch:0393 | align_epoch:0.396
# iter:0066 epoch:0394 | align_epoch:0.389
# iter:0066 epoch:0395 | align_epoch:0.401
# iter:0066 epoch:0396 | align_epoch:0.413
# iter:0067 epoch:0397 | align_epoch:0.380
# iter:0067 epoch:0398 | align_epoch:0.387
# iter:0067 epoch:0399 | align_epoch:0.402
# iter:0067 epoch:0400 | align_epoch:0.401
# iter:0067 epoch:0401 | align_epoch:0.388
# iter:0067 epoch:0402 | align_epoch:0.440
# iter:0068 epoch:0403 | align_epoch:0.376
# iter:0068 epoch:0404 | align_epoch:0.410
# iter:0068 epoch:0405 | align_epoch:0.397
# iter:0068 epoch:0406 | align_epoch:0.400
# iter:0068 epoch:0407 | align_epoch:0.408
# iter:0068 epoch:0408 | align_epoch:0.402
# iter:0069 epoch:0409 | align_epoch:0.397
# iter:0069 epoch:0410 | align_epoch:0.365
# iter:0069 epoch:0411 | align_epoch:0.410
# iter:0069 epoch:0412 | align_epoch:0.418
# iter:0069 epoch:0413 | align_epoch:0.402
# iter:0069 epoch:0414 | align_epoch:0.388
# iter:0070 epoch:0415 | align_epoch:0.405
# iter:0070 epoch:0416 | align_epoch:0.391
# iter:0070 epoch:0417 | align_epoch:0.396
# iter:0070 epoch:0418 | align_epoch:0.394
# iter:0070 epoch:0419 | align_epoch:0.397
# iter:0070 epoch:0420 | align_epoch:0.373
# iter:0071 epoch:0421 | align_epoch:0.386
# iter:0071 epoch:0422 | align_epoch:0.396
# iter:0071 epoch:0423 | align_epoch:0.408
# iter:0071 epoch:0424 | align_epoch:0.408
# iter:0071 epoch:0425 | align_epoch:0.387
# iter:0071 epoch:0426 | align_epoch:0.401
# iter:0072 epoch:0427 | align_epoch:0.395
# iter:0072 epoch:0428 | align_epoch:0.392
# iter:0072 epoch:0429 | align_epoch:0.413
# iter:0072 epoch:0430 | align_epoch:0.384
# iter:0072 epoch:0431 | align_epoch:0.403
# iter:0072 epoch:0432 | align_epoch:0.382
# iter:0073 epoch:0433 | align_epoch:0.409
# iter:0073 epoch:0434 | align_epoch:0.386
# iter:0073 epoch:0435 | align_epoch:0.408
# iter:0073 epoch:0436 | align_epoch:0.425
# iter:0073 epoch:0437 | align_epoch:0.396
# iter:0073 epoch:0438 | align_epoch:0.395
# iter:0074 epoch:0439 | align_epoch:0.383
# iter:0074 epoch:0440 | align_epoch:0.422
# iter:0074 epoch:0441 | align_epoch:0.416
# iter:0074 epoch:0442 | align_epoch:0.412
# iter:0074 epoch:0443 | align_epoch:0.409
# iter:0074 epoch:0444 | align_epoch:0.430
# iter:0075 epoch:0445 | align_epoch:0.404
# iter:0075 epoch:0446 | align_epoch:0.425
# iter:0075 epoch:0447 | align_epoch:0.434
# iter:0075 epoch:0448 | align_epoch:0.404
# iter:0075 epoch:0449 | align_epoch:0.406
# iter:0075 epoch:0450 | align_epoch:0.395
# iter:0076 epoch:0451 | align_epoch:0.401
# iter:0076 epoch:0452 | align_epoch:0.393
# iter:0076 epoch:0453 | align_epoch:0.421
# iter:0076 epoch:0454 | align_epoch:0.426
# iter:0076 epoch:0455 | align_epoch:0.399
# iter:0076 epoch:0456 | align_epoch:0.404
# iter:0077 epoch:0457 | align_epoch:0.390
# iter:0077 epoch:0458 | align_epoch:0.393
# iter:0077 epoch:0459 | align_epoch:0.416
# iter:0077 epoch:0460 | align_epoch:0.415
# iter:0077 epoch:0461 | align_epoch:0.419
# iter:0077 epoch:0462 | align_epoch:0.386
# iter:0078 epoch:0463 | align_epoch:0.443
# iter:0078 epoch:0464 | align_epoch:0.384
# iter:0078 epoch:0465 | align_epoch:0.400
# iter:0078 epoch:0466 | align_epoch:0.422
# iter:0078 epoch:0467 | align_epoch:0.412
# iter:0078 epoch:0468 | align_epoch:0.439
# iter:0079 epoch:0469 | align_epoch:0.404
# iter:0079 epoch:0470 | align_epoch:0.408
# iter:0079 epoch:0471 | align_epoch:0.405
# iter:0079 epoch:0472 | align_epoch:0.405
# iter:0079 epoch:0473 | align_epoch:0.398
# iter:0079 epoch:0474 | align_epoch:0.388
# iter:0080 epoch:0475 | align_epoch:0.414
# iter:0080 epoch:0476 | align_epoch:0.400
# iter:0080 epoch:0477 | align_epoch:0.408
# iter:0080 epoch:0478 | align_epoch:0.413
# iter:0080 epoch:0479 | align_epoch:0.425
# iter:0080 epoch:0480 | align_epoch:0.417
# iter:0081 epoch:0481 | align_epoch:0.417
# iter:0081 epoch:0482 | align_epoch:0.410
# iter:0081 epoch:0483 | align_epoch:0.424
# iter:0081 epoch:0484 | align_epoch:0.399
# iter:0081 epoch:0485 | align_epoch:0.396
# iter:0081 epoch:0486 | align_epoch:0.419
# iter:0082 epoch:0487 | align_epoch:0.411
# iter:0082 epoch:0488 | align_epoch:0.410
# iter:0082 epoch:0489 | align_epoch:0.409
# iter:0082 epoch:0490 | align_epoch:0.409
# iter:0082 epoch:0491 | align_epoch:0.405
# iter:0082 epoch:0492 | align_epoch:0.453
# iter:0083 epoch:0493 | align_epoch:0.421
# iter:0083 epoch:0494 | align_epoch:0.398
# iter:0083 epoch:0495 | align_epoch:0.412
# iter:0083 epoch:0496 | align_epoch:0.421
# iter:0083 epoch:0497 | align_epoch:0.425
# iter:0083 epoch:0498 | align_epoch:0.441
# iter:0084 epoch:0499 | align_epoch:0.414
# iter:0084 epoch:0500 | align_epoch:0.398
# iter:0084 epoch:0501 | align_epoch:0.404
# iter:0084 epoch:0502 | align_epoch:0.435
# iter:0084 epoch:0503 | align_epoch:0.407
# iter:0084 epoch:0504 | align_epoch:0.416
# iter:0085 epoch:0505 | align_epoch:0.406
# iter:0085 epoch:0506 | align_epoch:0.441
# iter:0085 epoch:0507 | align_epoch:0.406
# iter:0085 epoch:0508 | align_epoch:0.410
# iter:0085 epoch:0509 | align_epoch:0.404
# iter:0085 epoch:0510 | align_epoch:0.408
# iter:0086 epoch:0511 | align_epoch:0.429
# iter:0086 epoch:0512 | align_epoch:0.414
# iter:0086 epoch:0513 | align_epoch:0.416
# iter:0086 epoch:0514 | align_epoch:0.432
# iter:0086 epoch:0515 | align_epoch:0.405
# iter:0086 epoch:0516 | align_epoch:0.405
# iter:0087 epoch:0517 | align_epoch:0.403
# iter:0087 epoch:0518 | align_epoch:0.402
# iter:0087 epoch:0519 | align_epoch:0.404
# iter:0087 epoch:0520 | align_epoch:0.410
# iter:0087 epoch:0521 | align_epoch:0.413
# iter:0087 epoch:0522 | align_epoch:0.447
# iter:0088 epoch:0523 | align_epoch:0.413
# iter:0088 epoch:0524 | align_epoch:0.407
# iter:0088 epoch:0525 | align_epoch:0.430
# iter:0088 epoch:0526 | align_epoch:0.406
# iter:0088 epoch:0527 | align_epoch:0.414
# iter:0088 epoch:0528 | align_epoch:0.437
# iter:0089 epoch:0529 | align_epoch:0.419
# iter:0089 epoch:0530 | align_epoch:0.415
# iter:0089 epoch:0531 | align_epoch:0.404
# iter:0089 epoch:0532 | align_epoch:0.427
# iter:0089 epoch:0533 | align_epoch:0.408
# iter:0089 epoch:0534 | align_epoch:0.425
# iter:0090 epoch:0535 | align_epoch:0.399
# iter:0090 epoch:0536 | align_epoch:0.434
# iter:0090 epoch:0537 | align_epoch:0.410
# iter:0090 epoch:0538 | align_epoch:0.422
# iter:0090 epoch:0539 | align_epoch:0.420
# iter:0090 epoch:0540 | align_epoch:0.450
# iter:0091 epoch:0541 | align_epoch:0.417
# iter:0091 epoch:0542 | align_epoch:0.425
# iter:0091 epoch:0543 | align_epoch:0.407
# iter:0091 epoch:0544 | align_epoch:0.416
# iter:0091 epoch:0545 | align_epoch:0.428
# iter:0091 epoch:0546 | align_epoch:0.408
# iter:0092 epoch:0547 | align_epoch:0.391
# iter:0092 epoch:0548 | align_epoch:0.417
# iter:0092 epoch:0549 | align_epoch:0.431
# iter:0092 epoch:0550 | align_epoch:0.410
# iter:0092 epoch:0551 | align_epoch:0.432
# iter:0092 epoch:0552 | align_epoch:0.454
# iter:0093 epoch:0553 | align_epoch:0.431
# iter:0093 epoch:0554 | align_epoch:0.421
# iter:0093 epoch:0555 | align_epoch:0.436
# iter:0093 epoch:0556 | align_epoch:0.398
# iter:0093 epoch:0557 | align_epoch:0.410
# iter:0093 epoch:0558 | align_epoch:0.411
# iter:0094 epoch:0559 | align_epoch:0.405
# iter:0094 epoch:0560 | align_epoch:0.445
# iter:0094 epoch:0561 | align_epoch:0.442
# iter:0094 epoch:0562 | align_epoch:0.441
# iter:0094 epoch:0563 | align_epoch:0.403
# iter:0094 epoch:0564 | align_epoch:0.417
# iter:0095 epoch:0565 | align_epoch:0.439
# iter:0095 epoch:0566 | align_epoch:0.418
# iter:0095 epoch:0567 | align_epoch:0.410
# iter:0095 epoch:0568 | align_epoch:0.396
# iter:0095 epoch:0569 | align_epoch:0.428
# iter:0095 epoch:0570 | align_epoch:0.407
# iter:0096 epoch:0571 | align_epoch:0.420
# iter:0096 epoch:0572 | align_epoch:0.407
# iter:0096 epoch:0573 | align_epoch:0.420
# iter:0096 epoch:0574 | align_epoch:0.433
# iter:0096 epoch:0575 | align_epoch:0.429
# iter:0096 epoch:0576 | align_epoch:0.419
# iter:0097 epoch:0577 | align_epoch:0.414
# iter:0097 epoch:0578 | align_epoch:0.453
# iter:0097 epoch:0579 | align_epoch:0.409
# iter:0097 epoch:0580 | align_epoch:0.434
# iter:0097 epoch:0581 | align_epoch:0.430
# iter:0097 epoch:0582 | align_epoch:0.415
# iter:0098 epoch:0583 | align_epoch:0.399
# iter:0098 epoch:0584 | align_epoch:0.432
# iter:0098 epoch:0585 | align_epoch:0.429
# iter:0098 epoch:0586 | align_epoch:0.414
# iter:0098 epoch:0587 | align_epoch:0.408
# iter:0098 epoch:0588 | align_epoch:0.434
# iter:0099 epoch:0589 | align_epoch:0.421
# iter:0099 epoch:0590 | align_epoch:0.433
# iter:0099 epoch:0591 | align_epoch:0.424
# iter:0099 epoch:0592 | align_epoch:0.440
# iter:0099 epoch:0593 | align_epoch:0.407
# iter:0099 epoch:0594 | align_epoch:0.444
# iter:0100 epoch:0595 | align_epoch:0.422
# iter:0100 epoch:0596 | align_epoch:0.435
# iter:0100 epoch:0597 | align_epoch:0.431
# iter:0100 epoch:0598 | align_epoch:0.406
# iter:0100 epoch:0599 | align_epoch:0.424
# iter:0100 epoch:0600 | align_epoch:0.432
# iter:0101 epoch:0601 | align_epoch:0.434
# iter:0101 epoch:0602 | align_epoch:0.409
# iter:0101 epoch:0603 | align_epoch:0.420
# iter:0101 epoch:0604 | align_epoch:0.421
# iter:0101 epoch:0605 | align_epoch:0.432
# iter:0101 epoch:0606 | align_epoch:0.471
# iter:0102 epoch:0607 | align_epoch:0.432
# iter:0102 epoch:0608 | align_epoch:0.445
# iter:0102 epoch:0609 | align_epoch:0.408
# iter:0102 epoch:0610 | align_epoch:0.439
# iter:0102 epoch:0611 | align_epoch:0.436
# iter:0102 epoch:0612 | align_epoch:0.409
# iter:0103 epoch:0613 | align_epoch:0.429
# iter:0103 epoch:0614 | align_epoch:0.421
# iter:0103 epoch:0615 | align_epoch:0.403
# iter:0103 epoch:0616 | align_epoch:0.418
# iter:0103 epoch:0617 | align_epoch:0.442
# iter:0103 epoch:0618 | align_epoch:0.370
# iter:0104 epoch:0619 | align_epoch:0.420
# iter:0104 epoch:0620 | align_epoch:0.432
# iter:0104 epoch:0621 | align_epoch:0.423
# iter:0104 epoch:0622 | align_epoch:0.406
# iter:0104 epoch:0623 | align_epoch:0.437
# iter:0104 epoch:0624 | align_epoch:0.477
# iter:0105 epoch:0625 | align_epoch:0.415
# iter:0105 epoch:0626 | align_epoch:0.439
# iter:0105 epoch:0627 | align_epoch:0.442
# iter:0105 epoch:0628 | align_epoch:0.427
# iter:0105 epoch:0629 | align_epoch:0.421
# iter:0105 epoch:0630 | align_epoch:0.427
# iter:0106 epoch:0631 | align_epoch:0.441
# iter:0106 epoch:0632 | align_epoch:0.419
# iter:0106 epoch:0633 | align_epoch:0.441
# iter:0106 epoch:0634 | align_epoch:0.432
# iter:0106 epoch:0635 | align_epoch:0.417
# iter:0106 epoch:0636 | align_epoch:0.471
# iter:0107 epoch:0637 | align_epoch:0.406
# iter:0107 epoch:0638 | align_epoch:0.442
# iter:0107 epoch:0639 | align_epoch:0.421
# iter:0107 epoch:0640 | align_epoch:0.451
# iter:0107 epoch:0641 | align_epoch:0.429
# iter:0107 epoch:0642 | align_epoch:0.427
# iter:0108 epoch:0643 | align_epoch:0.448
# iter:0108 epoch:0644 | align_epoch:0.413
# iter:0108 epoch:0645 | align_epoch:0.425
# iter:0108 epoch:0646 | align_epoch:0.440
# iter:0108 epoch:0647 | align_epoch:0.422
# iter:0108 epoch:0648 | align_epoch:0.396
# iter:0109 epoch:0649 | align_epoch:0.430
# iter:0109 epoch:0650 | align_epoch:0.411
# iter:0109 epoch:0651 | align_epoch:0.420
# iter:0109 epoch:0652 | align_epoch:0.435
# iter:0109 epoch:0653 | align_epoch:0.413
# iter:0109 epoch:0654 | align_epoch:0.411
# iter:0110 epoch:0655 | align_epoch:0.417
# iter:0110 epoch:0656 | align_epoch:0.449
# iter:0110 epoch:0657 | align_epoch:0.423
# iter:0110 epoch:0658 | align_epoch:0.427
# iter:0110 epoch:0659 | align_epoch:0.430
# iter:0110 epoch:0660 | align_epoch:0.398
# iter:0111 epoch:0661 | align_epoch:0.423
# iter:0111 epoch:0662 | align_epoch:0.425
# iter:0111 epoch:0663 | align_epoch:0.431
# iter:0111 epoch:0664 | align_epoch:0.418
# iter:0111 epoch:0665 | align_epoch:0.442
# iter:0111 epoch:0666 | align_epoch:0.439
# iter:0112 epoch:0667 | align_epoch:0.430
# iter:0112 epoch:0668 | align_epoch:0.443
# iter:0112 epoch:0669 | align_epoch:0.419
# iter:0112 epoch:0670 | align_epoch:0.433
# iter:0112 epoch:0671 | align_epoch:0.423
# iter:0112 epoch:0672 | align_epoch:0.428
# iter:0113 epoch:0673 | align_epoch:0.427
# iter:0113 epoch:0674 | align_epoch:0.465
# iter:0113 epoch:0675 | align_epoch:0.424
# iter:0113 epoch:0676 | align_epoch:0.426
# iter:0113 epoch:0677 | align_epoch:0.420
# iter:0113 epoch:0678 | align_epoch:0.441
# iter:0114 epoch:0679 | align_epoch:0.427
# iter:0114 epoch:0680 | align_epoch:0.433
# iter:0114 epoch:0681 | align_epoch:0.427
# iter:0114 epoch:0682 | align_epoch:0.432
# iter:0114 epoch:0683 | align_epoch:0.431
# iter:0114 epoch:0684 | align_epoch:0.482
# iter:0115 epoch:0685 | align_epoch:0.443
# iter:0115 epoch:0686 | align_epoch:0.425
# iter:0115 epoch:0687 | align_epoch:0.417
# iter:0115 epoch:0688 | align_epoch:0.419
# iter:0115 epoch:0689 | align_epoch:0.433
# iter:0115 epoch:0690 | align_epoch:0.434
# iter:0116 epoch:0691 | align_epoch:0.438
# iter:0116 epoch:0692 | align_epoch:0.416
# iter:0116 epoch:0693 | align_epoch:0.429
# iter:0116 epoch:0694 | align_epoch:0.430
# iter:0116 epoch:0695 | align_epoch:0.430
# iter:0116 epoch:0696 | align_epoch:0.408
# iter:0117 epoch:0697 | align_epoch:0.411
# iter:0117 epoch:0698 | align_epoch:0.432
# iter:0117 epoch:0699 | align_epoch:0.446
# iter:0117 epoch:0700 | align_epoch:0.427
# iter:0117 epoch:0701 | align_epoch:0.427
# iter:0117 epoch:0702 | align_epoch:0.428
# iter:0118 epoch:0703 | align_epoch:0.416
# iter:0118 epoch:0704 | align_epoch:0.414
# iter:0118 epoch:0705 | align_epoch:0.440
# iter:0118 epoch:0706 | align_epoch:0.434
# iter:0118 epoch:0707 | align_epoch:0.431
# iter:0118 epoch:0708 | align_epoch:0.470
# iter:0119 epoch:0709 | align_epoch:0.450
# iter:0119 epoch:0710 | align_epoch:0.427
# iter:0119 epoch:0711 | align_epoch:0.440
# iter:0119 epoch:0712 | align_epoch:0.418
# iter:0119 epoch:0713 | align_epoch:0.451
# iter:0119 epoch:0714 | align_epoch:0.454
# iter:0120 epoch:0715 | align_epoch:0.443
# iter:0120 epoch:0716 | align_epoch:0.429
# iter:0120 epoch:0717 | align_epoch:0.437
# iter:0120 epoch:0718 | align_epoch:0.423
# iter:0120 epoch:0719 | align_epoch:0.451
# iter:0120 epoch:0720 | align_epoch:0.432
# iter:0121 epoch:0721 | align_epoch:0.422
# iter:0121 epoch:0722 | align_epoch:0.426
# iter:0121 epoch:0723 | align_epoch:0.454
# iter:0121 epoch:0724 | align_epoch:0.445
# iter:0121 epoch:0725 | align_epoch:0.432
# iter:0121 epoch:0726 | align_epoch:0.411
# iter:0122 epoch:0727 | align_epoch:0.429
# iter:0122 epoch:0728 | align_epoch:0.437
# iter:0122 epoch:0729 | align_epoch:0.442
# iter:0122 epoch:0730 | align_epoch:0.431
# iter:0122 epoch:0731 | align_epoch:0.445
# iter:0122 epoch:0732 | align_epoch:0.456
# iter:0123 epoch:0733 | align_epoch:0.430
# iter:0123 epoch:0734 | align_epoch:0.452
# iter:0123 epoch:0735 | align_epoch:0.429
# iter:0123 epoch:0736 | align_epoch:0.444
# iter:0123 epoch:0737 | align_epoch:0.458
# iter:0123 epoch:0738 | align_epoch:0.421
# iter:0124 epoch:0739 | align_epoch:0.435
# iter:0124 epoch:0740 | align_epoch:0.439
# iter:0124 epoch:0741 | align_epoch:0.457
# iter:0124 epoch:0742 | align_epoch:0.435
# iter:0124 epoch:0743 | align_epoch:0.426
# iter:0124 epoch:0744 | align_epoch:0.434
# iter:0125 epoch:0745 | align_epoch:0.425
# iter:0125 epoch:0746 | align_epoch:0.428
# iter:0125 epoch:0747 | align_epoch:0.456
# iter:0125 epoch:0748 | align_epoch:0.419
# iter:0125 epoch:0749 | align_epoch:0.455
# iter:0125 epoch:0750 | align_epoch:0.438
# iter:0126 epoch:0751 | align_epoch:0.420
# iter:0126 epoch:0752 | align_epoch:0.437
# iter:0126 epoch:0753 | align_epoch:0.443
# iter:0126 epoch:0754 | align_epoch:0.455
# iter:0126 epoch:0755 | align_epoch:0.422
# iter:0126 epoch:0756 | align_epoch:0.411
# iter:0127 epoch:0757 | align_epoch:0.426
# iter:0127 epoch:0758 | align_epoch:0.434
# iter:0127 epoch:0759 | align_epoch:0.421
# iter:0127 epoch:0760 | align_epoch:0.421
# iter:0127 epoch:0761 | align_epoch:0.442
# iter:0127 epoch:0762 | align_epoch:0.428
# iter:0128 epoch:0763 | align_epoch:0.452
# iter:0128 epoch:0764 | align_epoch:0.435
# iter:0128 epoch:0765 | align_epoch:0.424
# iter:0128 epoch:0766 | align_epoch:0.406
# iter:0128 epoch:0767 | align_epoch:0.456
# iter:0128 epoch:0768 | align_epoch:0.434
# iter:0129 epoch:0769 | align_epoch:0.452
# iter:0129 epoch:0770 | align_epoch:0.415
# iter:0129 epoch:0771 | align_epoch:0.438
# iter:0129 epoch:0772 | align_epoch:0.423
# iter:0129 epoch:0773 | align_epoch:0.444
# iter:0129 epoch:0774 | align_epoch:0.474
# iter:0130 epoch:0775 | align_epoch:0.421
# iter:0130 epoch:0776 | align_epoch:0.423
# iter:0130 epoch:0777 | align_epoch:0.463
# iter:0130 epoch:0778 | align_epoch:0.449
# iter:0130 epoch:0779 | align_epoch:0.435
# iter:0130 epoch:0780 | align_epoch:0.430
# iter:0131 epoch:0781 | align_epoch:0.426
# iter:0131 epoch:0782 | align_epoch:0.446
# iter:0131 epoch:0783 | align_epoch:0.463
# iter:0131 epoch:0784 | align_epoch:0.452
# iter:0131 epoch:0785 | align_epoch:0.425
# iter:0131 epoch:0786 | align_epoch:0.463
# iter:0132 epoch:0787 | align_epoch:0.419
# iter:0132 epoch:0788 | align_epoch:0.436
# iter:0132 epoch:0789 | align_epoch:0.441
# iter:0132 epoch:0790 | align_epoch:0.445
# iter:0132 epoch:0791 | align_epoch:0.415
# iter:0132 epoch:0792 | align_epoch:0.445
# iter:0133 epoch:0793 | align_epoch:0.414
# iter:0133 epoch:0794 | align_epoch:0.405
# iter:0133 epoch:0795 | align_epoch:0.453
# iter:0133 epoch:0796 | align_epoch:0.479
# iter:0133 epoch:0797 | align_epoch:0.449
# iter:0133 epoch:0798 | align_epoch:0.501
# iter:0134 epoch:0799 | align_epoch:0.448
# iter:0134 epoch:0800 | align_epoch:0.421
# iter:0134 epoch:0801 | align_epoch:0.425
# iter:0134 epoch:0802 | align_epoch:0.440
# iter:0134 epoch:0803 | align_epoch:0.456
# iter:0134 epoch:0804 | align_epoch:0.443
# iter:0135 epoch:0805 | align_epoch:0.424
# iter:0135 epoch:0806 | align_epoch:0.441
# iter:0135 epoch:0807 | align_epoch:0.447
# iter:0135 epoch:0808 | align_epoch:0.418
# iter:0135 epoch:0809 | align_epoch:0.449
# iter:0135 epoch:0810 | align_epoch:0.416
# iter:0136 epoch:0811 | align_epoch:0.438
# iter:0136 epoch:0812 | align_epoch:0.432
# iter:0136 epoch:0813 | align_epoch:0.454
# iter:0136 epoch:0814 | align_epoch:0.430
# iter:0136 epoch:0815 | align_epoch:0.452
# iter:0136 epoch:0816 | align_epoch:0.454
# iter:0137 epoch:0817 | align_epoch:0.442
# iter:0137 epoch:0818 | align_epoch:0.461
# iter:0137 epoch:0819 | align_epoch:0.452
# iter:0137 epoch:0820 | align_epoch:0.422
# iter:0137 epoch:0821 | align_epoch:0.426
# iter:0137 epoch:0822 | align_epoch:0.407
# iter:0138 epoch:0823 | align_epoch:0.452
# iter:0138 epoch:0824 | align_epoch:0.441
# iter:0138 epoch:0825 | align_epoch:0.434
# iter:0138 epoch:0826 | align_epoch:0.435
# iter:0138 epoch:0827 | align_epoch:0.467
# iter:0138 epoch:0828 | align_epoch:0.476
# iter:0139 epoch:0829 | align_epoch:0.431
# iter:0139 epoch:0830 | align_epoch:0.447
# iter:0139 epoch:0831 | align_epoch:0.448
# iter:0139 epoch:0832 | align_epoch:0.459
# iter:0139 epoch:0833 | align_epoch:0.462
# iter:0139 epoch:0834 | align_epoch:0.427
# iter:0140 epoch:0835 | align_epoch:0.432
# iter:0140 epoch:0836 | align_epoch:0.436
# iter:0140 epoch:0837 | align_epoch:0.443
# iter:0140 epoch:0838 | align_epoch:0.446
# iter:0140 epoch:0839 | align_epoch:0.465
# iter:0140 epoch:0840 | align_epoch:0.451
# iter:0141 epoch:0841 | align_epoch:0.420
# iter:0141 epoch:0842 | align_epoch:0.442
# iter:0141 epoch:0843 | align_epoch:0.433
# iter:0141 epoch:0844 | align_epoch:0.450
# iter:0141 epoch:0845 | align_epoch:0.470
# iter:0141 epoch:0846 | align_epoch:0.454
# iter:0142 epoch:0847 | align_epoch:0.437
# iter:0142 epoch:0848 | align_epoch:0.440
# iter:0142 epoch:0849 | align_epoch:0.427
# iter:0142 epoch:0850 | align_epoch:0.432
# iter:0142 epoch:0851 | align_epoch:0.446
# iter:0142 epoch:0852 | align_epoch:0.472
# iter:0143 epoch:0853 | align_epoch:0.421
# iter:0143 epoch:0854 | align_epoch:0.436
# iter:0143 epoch:0855 | align_epoch:0.459
# iter:0143 epoch:0856 | align_epoch:0.440
# iter:0143 epoch:0857 | align_epoch:0.423
# iter:0143 epoch:0858 | align_epoch:0.413
# iter:0144 epoch:0859 | align_epoch:0.441
# iter:0144 epoch:0860 | align_epoch:0.448
# iter:0144 epoch:0861 | align_epoch:0.452
# iter:0144 epoch:0862 | align_epoch:0.461
# iter:0144 epoch:0863 | align_epoch:0.454
# iter:0144 epoch:0864 | align_epoch:0.441
# iter:0145 epoch:0865 | align_epoch:0.450
# iter:0145 epoch:0866 | align_epoch:0.450
# iter:0145 epoch:0867 | align_epoch:0.451
# iter:0145 epoch:0868 | align_epoch:0.458
# iter:0145 epoch:0869 | align_epoch:0.436
# iter:0145 epoch:0870 | align_epoch:0.448
# iter:0146 epoch:0871 | align_epoch:0.462
# iter:0146 epoch:0872 | align_epoch:0.429
# iter:0146 epoch:0873 | align_epoch:0.417
# iter:0146 epoch:0874 | align_epoch:0.456
# iter:0146 epoch:0875 | align_epoch:0.455
# iter:0146 epoch:0876 | align_epoch:0.422
# iter:0147 epoch:0877 | align_epoch:0.441
# iter:0147 epoch:0878 | align_epoch:0.433
# iter:0147 epoch:0879 | align_epoch:0.461
# iter:0147 epoch:0880 | align_epoch:0.462
# iter:0147 epoch:0881 | align_epoch:0.443
# iter:0147 epoch:0882 | align_epoch:0.459
# iter:0148 epoch:0883 | align_epoch:0.464
# iter:0148 epoch:0884 | align_epoch:0.435
# iter:0148 epoch:0885 | align_epoch:0.435
# iter:0148 epoch:0886 | align_epoch:0.428
# iter:0148 epoch:0887 | align_epoch:0.466
# iter:0148 epoch:0888 | align_epoch:0.435
# iter:0149 epoch:0889 | align_epoch:0.458
# iter:0149 epoch:0890 | align_epoch:0.424
# iter:0149 epoch:0891 | align_epoch:0.433
# iter:0149 epoch:0892 | align_epoch:0.425
# iter:0149 epoch:0893 | align_epoch:0.431
# iter:0149 epoch:0894 | align_epoch:0.428
# iter:0150 epoch:0895 | align_epoch:0.442
# iter:0150 epoch:0896 | align_epoch:0.433
# iter:0150 epoch:0897 | align_epoch:0.463
# iter:0150 epoch:0898 | align_epoch:0.430
# iter:0150 epoch:0899 | align_epoch:0.441
# iter:0150 epoch:0900 | align_epoch:0.448
# iter:0151 epoch:0901 | align_epoch:0.429
# iter:0151 epoch:0902 | align_epoch:0.426
# iter:0151 epoch:0903 | align_epoch:0.484
# iter:0151 epoch:0904 | align_epoch:0.441
# iter:0151 epoch:0905 | align_epoch:0.463
# iter:0151 epoch:0906 | align_epoch:0.433
# iter:0152 epoch:0907 | align_epoch:0.453
# iter:0152 epoch:0908 | align_epoch:0.459
# iter:0152 epoch:0909 | align_epoch:0.430
# iter:0152 epoch:0910 | align_epoch:0.440
# iter:0152 epoch:0911 | align_epoch:0.456
# iter:0152 epoch:0912 | align_epoch:0.416
# iter:0153 epoch:0913 | align_epoch:0.441
# iter:0153 epoch:0914 | align_epoch:0.446
# iter:0153 epoch:0915 | align_epoch:0.472
# iter:0153 epoch:0916 | align_epoch:0.453
# iter:0153 epoch:0917 | align_epoch:0.416
# iter:0153 epoch:0918 | align_epoch:0.484
# iter:0154 epoch:0919 | align_epoch:0.452
# iter:0154 epoch:0920 | align_epoch:0.425
# iter:0154 epoch:0921 | align_epoch:0.431
# iter:0154 epoch:0922 | align_epoch:0.472
# iter:0154 epoch:0923 | align_epoch:0.452
# iter:0154 epoch:0924 | align_epoch:0.432
# iter:0155 epoch:0925 | align_epoch:0.438
# iter:0155 epoch:0926 | align_epoch:0.440
# iter:0155 epoch:0927 | align_epoch:0.462
# iter:0155 epoch:0928 | align_epoch:0.438
# iter:0155 epoch:0929 | align_epoch:0.444
# iter:0155 epoch:0930 | align_epoch:0.448
# iter:0156 epoch:0931 | align_epoch:0.464
# iter:0156 epoch:0932 | align_epoch:0.440
# iter:0156 epoch:0933 | align_epoch:0.437
# iter:0156 epoch:0934 | align_epoch:0.459
# iter:0156 epoch:0935 | align_epoch:0.433
# iter:0156 epoch:0936 | align_epoch:0.426
# iter:0157 epoch:0937 | align_epoch:0.443
# iter:0157 epoch:0938 | align_epoch:0.418
# iter:0157 epoch:0939 | align_epoch:0.444
# iter:0157 epoch:0940 | align_epoch:0.424
# iter:0157 epoch:0941 | align_epoch:0.458
# iter:0157 epoch:0942 | align_epoch:0.432
# iter:0158 epoch:0943 | align_epoch:0.450
# iter:0158 epoch:0944 | align_epoch:0.443
# iter:0158 epoch:0945 | align_epoch:0.448
# iter:0158 epoch:0946 | align_epoch:0.449
# iter:0158 epoch:0947 | align_epoch:0.467
# iter:0158 epoch:0948 | align_epoch:0.437
# iter:0159 epoch:0949 | align_epoch:0.431
# iter:0159 epoch:0950 | align_epoch:0.433
# iter:0159 epoch:0951 | align_epoch:0.461
# iter:0159 epoch:0952 | align_epoch:0.481
# iter:0159 epoch:0953 | align_epoch:0.444
# iter:0159 epoch:0954 | align_epoch:0.446
# iter:0160 epoch:0955 | align_epoch:0.476
# iter:0160 epoch:0956 | align_epoch:0.440
# iter:0160 epoch:0957 | align_epoch:0.441
# iter:0160 epoch:0958 | align_epoch:0.445
# iter:0160 epoch:0959 | align_epoch:0.448
# iter:0160 epoch:0960 | align_epoch:0.470
# iter:0161 epoch:0961 | align_epoch:0.439
# iter:0161 epoch:0962 | align_epoch:0.455
# iter:0161 epoch:0963 | align_epoch:0.454
# iter:0161 epoch:0964 | align_epoch:0.448
# iter:0161 epoch:0965 | align_epoch:0.439
# iter:0161 epoch:0966 | align_epoch:0.453
# iter:0162 epoch:0967 | align_epoch:0.438
# iter:0162 epoch:0968 | align_epoch:0.460
# iter:0162 epoch:0969 | align_epoch:0.420
# iter:0162 epoch:0970 | align_epoch:0.429
# iter:0162 epoch:0971 | align_epoch:0.454
# iter:0162 epoch:0972 | align_epoch:0.457
# iter:0163 epoch:0973 | align_epoch:0.455
# iter:0163 epoch:0974 | align_epoch:0.458
# iter:0163 epoch:0975 | align_epoch:0.487
# iter:0163 epoch:0976 | align_epoch:0.436
# iter:0163 epoch:0977 | align_epoch:0.438
# iter:0163 epoch:0978 | align_epoch:0.432
# iter:0164 epoch:0979 | align_epoch:0.437
# iter:0164 epoch:0980 | align_epoch:0.444
# iter:0164 epoch:0981 | align_epoch:0.460
# iter:0164 epoch:0982 | align_epoch:0.475
# iter:0164 epoch:0983 | align_epoch:0.455
# iter:0164 epoch:0984 | align_epoch:0.424
# iter:0165 epoch:0985 | align_epoch:0.469
# iter:0165 epoch:0986 | align_epoch:0.435
# iter:0165 epoch:0987 | align_epoch:0.418
# iter:0165 epoch:0988 | align_epoch:0.432
# iter:0165 epoch:0989 | align_epoch:0.465
# iter:0165 epoch:0990 | align_epoch:0.464
# iter:0166 epoch:0991 | align_epoch:0.449
# iter:0166 epoch:0992 | align_epoch:0.445
# iter:0166 epoch:0993 | align_epoch:0.459
# iter:0166 epoch:0994 | align_epoch:0.464
# iter:0166 epoch:0995 | align_epoch:0.474
# iter:0166 epoch:0996 | align_epoch:0.425
# iter:0167 epoch:0997 | align_epoch:0.461
# iter:0167 epoch:0998 | align_epoch:0.471
# iter:0167 epoch:0999 | align_epoch:0.429
# iter:0167 epoch:1000 | align_epoch:0.442
# iter:0167 epoch:1001 | align_epoch:0.461
# iter:0167 epoch:1002 | align_epoch:0.440
# iter:0168 epoch:1003 | align_epoch:0.469
# iter:0168 epoch:1004 | align_epoch:0.449
# iter:0168 epoch:1005 | align_epoch:0.435
# iter:0168 epoch:1006 | align_epoch:0.415
# iter:0168 epoch:1007 | align_epoch:0.463
# iter:0168 epoch:1008 | align_epoch:0.449
# iter:0169 epoch:1009 | align_epoch:0.446
# iter:0169 epoch:1010 | align_epoch:0.470
# iter:0169 epoch:1011 | align_epoch:0.459
# iter:0169 epoch:1012 | align_epoch:0.455
# iter:0169 epoch:1013 | align_epoch:0.448
# iter:0169 epoch:1014 | align_epoch:0.451
# iter:0170 epoch:1015 | align_epoch:0.471
# iter:0170 epoch:1016 | align_epoch:0.439
# iter:0170 epoch:1017 | align_epoch:0.439
# iter:0170 epoch:1018 | align_epoch:0.456
# iter:0170 epoch:1019 | align_epoch:0.428
# iter:0170 epoch:1020 | align_epoch:0.487
# iter:0171 epoch:1021 | align_epoch:0.452
# iter:0171 epoch:1022 | align_epoch:0.456
# iter:0171 epoch:1023 | align_epoch:0.445
# iter:0171 epoch:1024 | align_epoch:0.460
# iter:0171 epoch:1025 | align_epoch:0.447
# iter:0171 epoch:1026 | align_epoch:0.457
# iter:0172 epoch:1027 | align_epoch:0.460
# iter:0172 epoch:1028 | align_epoch:0.453
# iter:0172 epoch:1029 | align_epoch:0.442
# iter:0172 epoch:1030 | align_epoch:0.430
# iter:0172 epoch:1031 | align_epoch:0.449
# iter:0172 epoch:1032 | align_epoch:0.457
# iter:0173 epoch:1033 | align_epoch:0.428
# iter:0173 epoch:1034 | align_epoch:0.449
# iter:0173 epoch:1035 | align_epoch:0.418
# iter:0173 epoch:1036 | align_epoch:0.468
# iter:0173 epoch:1037 | align_epoch:0.482
# iter:0173 epoch:1038 | align_epoch:0.478
# iter:0174 epoch:1039 | align_epoch:0.450
# iter:0174 epoch:1040 | align_epoch:0.452
# iter:0174 epoch:1041 | align_epoch:0.437
# iter:0174 epoch:1042 | align_epoch:0.457
# iter:0174 epoch:1043 | align_epoch:0.453
# iter:0174 epoch:1044 | align_epoch:0.481
# iter:0175 epoch:1045 | align_epoch:0.454
# iter:0175 epoch:1046 | align_epoch:0.470
# iter:0175 epoch:1047 | align_epoch:0.447
# iter:0175 epoch:1048 | align_epoch:0.441
# iter:0175 epoch:1049 | align_epoch:0.440
# iter:0175 epoch:1050 | align_epoch:0.516
# iter:0176 epoch:1051 | align_epoch:0.451
# iter:0176 epoch:1052 | align_epoch:0.444
# iter:0176 epoch:1053 | align_epoch:0.461
# iter:0176 epoch:1054 | align_epoch:0.442
# iter:0176 epoch:1055 | align_epoch:0.440
# iter:0176 epoch:1056 | align_epoch:0.413
# iter:0177 epoch:1057 | align_epoch:0.430
# iter:0177 epoch:1058 | align_epoch:0.467
# iter:0177 epoch:1059 | align_epoch:0.456
# iter:0177 epoch:1060 | align_epoch:0.499
# iter:0177 epoch:1061 | align_epoch:0.439
# iter:0177 epoch:1062 | align_epoch:0.412
# iter:0178 epoch:1063 | align_epoch:0.451
# iter:0178 epoch:1064 | align_epoch:0.476
# iter:0178 epoch:1065 | align_epoch:0.432
# iter:0178 epoch:1066 | align_epoch:0.430
# iter:0178 epoch:1067 | align_epoch:0.479
# iter:0178 epoch:1068 | align_epoch:0.458
# iter:0179 epoch:1069 | align_epoch:0.443
# iter:0179 epoch:1070 | align_epoch:0.441
# iter:0179 epoch:1071 | align_epoch:0.457
# iter:0179 epoch:1072 | align_epoch:0.440
# iter:0179 epoch:1073 | align_epoch:0.470
# iter:0179 epoch:1074 | align_epoch:0.422
# iter:0180 epoch:1075 | align_epoch:0.434
# iter:0180 epoch:1076 | align_epoch:0.471
# iter:0180 epoch:1077 | align_epoch:0.441
# iter:0180 epoch:1078 | align_epoch:0.432
# iter:0180 epoch:1079 | align_epoch:0.444
# iter:0180 epoch:1080 | align_epoch:0.484
# iter:0181 epoch:1081 | align_epoch:0.470
# iter:0181 epoch:1082 | align_epoch:0.474
# iter:0181 epoch:1083 | align_epoch:0.413
# iter:0181 epoch:1084 | align_epoch:0.462
# iter:0181 epoch:1085 | align_epoch:0.483
# iter:0181 epoch:1086 | align_epoch:0.428
# iter:0182 epoch:1087 | align_epoch:0.439
# iter:0182 epoch:1088 | align_epoch:0.478
# iter:0182 epoch:1089 | align_epoch:0.434
# iter:0182 epoch:1090 | align_epoch:0.469
# iter:0182 epoch:1091 | align_epoch:0.418
# iter:0182 epoch:1092 | align_epoch:0.547
# iter:0183 epoch:1093 | align_epoch:0.468
# iter:0183 epoch:1094 | align_epoch:0.464
# iter:0183 epoch:1095 | align_epoch:0.465
# iter:0183 epoch:1096 | align_epoch:0.427
# iter:0183 epoch:1097 | align_epoch:0.463
# iter:0183 epoch:1098 | align_epoch:0.477
# iter:0184 epoch:1099 | align_epoch:0.443
# iter:0184 epoch:1100 | align_epoch:0.462
# iter:0184 epoch:1101 | align_epoch:0.465
# iter:0184 epoch:1102 | align_epoch:0.444
# iter:0184 epoch:1103 | align_epoch:0.446
# iter:0184 epoch:1104 | align_epoch:0.511
# iter:0185 epoch:1105 | align_epoch:0.456
# iter:0185 epoch:1106 | align_epoch:0.473
# iter:0185 epoch:1107 | align_epoch:0.474
# iter:0185 epoch:1108 | align_epoch:0.444
# iter:0185 epoch:1109 | align_epoch:0.457
# iter:0185 epoch:1110 | align_epoch:0.447
# iter:0186 epoch:1111 | align_epoch:0.451
# iter:0186 epoch:1112 | align_epoch:0.461
# iter:0186 epoch:1113 | align_epoch:0.432
# iter:0186 epoch:1114 | align_epoch:0.432
# iter:0186 epoch:1115 | align_epoch:0.450
# iter:0186 epoch:1116 | align_epoch:0.511
# iter:0187 epoch:1117 | align_epoch:0.439
# iter:0187 epoch:1118 | align_epoch:0.460
# iter:0187 epoch:1119 | align_epoch:0.426
# iter:0187 epoch:1120 | align_epoch:0.441
# iter:0187 epoch:1121 | align_epoch:0.472
# iter:0187 epoch:1122 | align_epoch:0.492
# iter:0188 epoch:1123 | align_epoch:0.473
# iter:0188 epoch:1124 | align_epoch:0.432
# iter:0188 epoch:1125 | align_epoch:0.478
# iter:0188 epoch:1126 | align_epoch:0.460
# iter:0188 epoch:1127 | align_epoch:0.432
# iter:0188 epoch:1128 | align_epoch:0.508
# iter:0189 epoch:1129 | align_epoch:0.459
# iter:0189 epoch:1130 | align_epoch:0.465
# iter:0189 epoch:1131 | align_epoch:0.449
# iter:0189 epoch:1132 | align_epoch:0.479
# iter:0189 epoch:1133 | align_epoch:0.438
# iter:0189 epoch:1134 | align_epoch:0.438
# iter:0190 epoch:1135 | align_epoch:0.423
# iter:0190 epoch:1136 | align_epoch:0.460
# iter:0190 epoch:1137 | align_epoch:0.485
# iter:0190 epoch:1138 | align_epoch:0.473
# iter:0190 epoch:1139 | align_epoch:0.464
# iter:0190 epoch:1140 | align_epoch:0.428
# iter:0191 epoch:1141 | align_epoch:0.471
# iter:0191 epoch:1142 | align_epoch:0.450
# iter:0191 epoch:1143 | align_epoch:0.458
# iter:0191 epoch:1144 | align_epoch:0.442
# iter:0191 epoch:1145 | align_epoch:0.448
# iter:0191 epoch:1146 | align_epoch:0.426
# iter:0192 epoch:1147 | align_epoch:0.473
# iter:0192 epoch:1148 | align_epoch:0.460
# iter:0192 epoch:1149 | align_epoch:0.448
# iter:0192 epoch:1150 | align_epoch:0.462
# iter:0192 epoch:1151 | align_epoch:0.452
# iter:0192 epoch:1152 | align_epoch:0.419
# iter:0193 epoch:1153 | align_epoch:0.414
# iter:0193 epoch:1154 | align_epoch:0.491
# iter:0193 epoch:1155 | align_epoch:0.467
# iter:0193 epoch:1156 | align_epoch:0.454
# iter:0193 epoch:1157 | align_epoch:0.452
# iter:0193 epoch:1158 | align_epoch:0.475
# iter:0194 epoch:1159 | align_epoch:0.469
# iter:0194 epoch:1160 | align_epoch:0.464
# iter:0194 epoch:1161 | align_epoch:0.449
# iter:0194 epoch:1162 | align_epoch:0.489
# iter:0194 epoch:1163 | align_epoch:0.444
# iter:0194 epoch:1164 | align_epoch:0.510
# iter:0195 epoch:1165 | align_epoch:0.439
# iter:0195 epoch:1166 | align_epoch:0.481
# iter:0195 epoch:1167 | align_epoch:0.464
# iter:0195 epoch:1168 | align_epoch:0.456
# iter:0195 epoch:1169 | align_epoch:0.477
# iter:0195 epoch:1170 | align_epoch:0.455
# ...
# iter:0456 epoch:2731 | align_epoch:0.466
# iter:0456 epoch:2732 | align_epoch:0.469
# iter:0456 epoch:2733 | align_epoch:0.487
# iter:0456 epoch:2734 | align_epoch:0.493
# iter:0456 epoch:2735 | align_epoch:0.482
# iter:0456 epoch:2736 | align_epoch:0.462
# iter:0457 epoch:2737 | align_epoch:0.464
# iter:0457 epoch:2738 | align_epoch:0.486
# iter:0457 epoch:2739 | align_epoch:0.476
# iter:0457 epoch:2740 | align_epoch:0.485
# iter:0457 epoch:2741 | align_epoch:0.498
# iter:0457 epoch:2742 | align_epoch:0.447
# iter:0458 epoch:2743 | align_epoch:0.499
# iter:0458 epoch:2744 | align_epoch:0.480
# iter:0458 epoch:2745 | align_epoch:0.469
# iter:0458 epoch:2746 | align_epoch:0.488
# iter:0458 epoch:2747 | align_epoch:0.472
# iter:0458 epoch:2748 | align_epoch:0.477
# iter:0459 epoch:2749 | align_epoch:0.503
# iter:0459 epoch:2750 | align_epoch:0.468
# iter:0459 epoch:2751 | align_epoch:0.472
# iter:0459 epoch:2752 | align_epoch:0.484
# iter:0459 epoch:2753 | align_epoch:0.485
# iter:0459 epoch:2754 | align_epoch:0.471
# iter:0460 epoch:2755 | align_epoch:0.514
# iter:0460 epoch:2756 | align_epoch:0.461
# iter:0460 epoch:2757 | align_epoch:0.498
# iter:0460 epoch:2758 | align_epoch:0.452
# iter:0460 epoch:2759 | align_epoch:0.472
# iter:0460 epoch:2760 | align_epoch:0.446
# iter:0461 epoch:2761 | align_epoch:0.491
# iter:0461 epoch:2762 | align_epoch:0.486
# iter:0461 epoch:2763 | align_epoch:0.486
# iter:0461 epoch:2764 | align_epoch:0.472
# iter:0461 epoch:2765 | align_epoch:0.474
# iter:0461 epoch:2766 | align_epoch:0.450
# iter:0462 epoch:2767 | align_epoch:0.470
# iter:0462 epoch:2768 | align_epoch:0.469
# iter:0462 epoch:2769 | align_epoch:0.483
# iter:0462 epoch:2770 | align_epoch:0.493
# iter:0462 epoch:2771 | align_epoch:0.478
# iter:0462 epoch:2772 | align_epoch:0.501
# iter:0463 epoch:2773 | align_epoch:0.525
# iter:0463 epoch:2774 | align_epoch:0.486
# iter:0463 epoch:2775 | align_epoch:0.461
# iter:0463 epoch:2776 | align_epoch:0.479
# iter:0463 epoch:2777 | align_epoch:0.487
# iter:0463 epoch:2778 | align_epoch:0.430
# iter:0464 epoch:2779 | align_epoch:0.461
# iter:0464 epoch:2780 | align_epoch:0.468
# iter:0464 epoch:2781 | align_epoch:0.477
# iter:0464 epoch:2782 | align_epoch:0.488
# iter:0464 epoch:2783 | align_epoch:0.445
# iter:0464 epoch:2784 | align_epoch:0.502
# iter:0465 epoch:2785 | align_epoch:0.469
# iter:0465 epoch:2786 | align_epoch:0.469
# iter:0465 epoch:2787 | align_epoch:0.484
# iter:0465 epoch:2788 | align_epoch:0.476
# iter:0465 epoch:2789 | align_epoch:0.479
# iter:0465 epoch:2790 | align_epoch:0.472
# iter:0466 epoch:2791 | align_epoch:0.495
# iter:0466 epoch:2792 | align_epoch:0.476
# iter:0466 epoch:2793 | align_epoch:0.474
# iter:0466 epoch:2794 | align_epoch:0.501
# iter:0466 epoch:2795 | align_epoch:0.489
# iter:0466 epoch:2796 | align_epoch:0.496
# iter:0467 epoch:2797 | align_epoch:0.481
# iter:0467 epoch:2798 | align_epoch:0.463
# iter:0467 epoch:2799 | align_epoch:0.486
# iter:0467 epoch:2800 | align_epoch:0.486
# iter:0467 epoch:2801 | align_epoch:0.500
# iter:0467 epoch:2802 | align_epoch:0.459
# iter:0468 epoch:2803 | align_epoch:0.461
# iter:0468 epoch:2804 | align_epoch:0.491
# iter:0468 epoch:2805 | align_epoch:0.465
# iter:0468 epoch:2806 | align_epoch:0.491
# iter:0468 epoch:2807 | align_epoch:0.474
# iter:0468 epoch:2808 | align_epoch:0.524
# iter:0469 epoch:2809 | align_epoch:0.489
# iter:0469 epoch:2810 | align_epoch:0.477
# iter:0469 epoch:2811 | align_epoch:0.478
# iter:0469 epoch:2812 | align_epoch:0.490
# iter:0469 epoch:2813 | align_epoch:0.492
# iter:0469 epoch:2814 | align_epoch:0.435
# iter:0470 epoch:2815 | align_epoch:0.507
# iter:0470 epoch:2816 | align_epoch:0.478
# iter:0470 epoch:2817 | align_epoch:0.498
# iter:0470 epoch:2818 | align_epoch:0.468
# iter:0470 epoch:2819 | align_epoch:0.471
# iter:0470 epoch:2820 | align_epoch:0.447
# iter:0471 epoch:2821 | align_epoch:0.466
# iter:0471 epoch:2822 | align_epoch:0.476
# iter:0471 epoch:2823 | align_epoch:0.484
# iter:0471 epoch:2824 | align_epoch:0.489
# iter:0471 epoch:2825 | align_epoch:0.484
# iter:0471 epoch:2826 | align_epoch:0.488
# iter:0472 epoch:2827 | align_epoch:0.461
# iter:0472 epoch:2828 | align_epoch:0.509
# iter:0472 epoch:2829 | align_epoch:0.495
# iter:0472 epoch:2830 | align_epoch:0.465
# iter:0472 epoch:2831 | align_epoch:0.493
# iter:0472 epoch:2832 | align_epoch:0.418
# iter:0473 epoch:2833 | align_epoch:0.484
# iter:0473 epoch:2834 | align_epoch:0.468
# iter:0473 epoch:2835 | align_epoch:0.473
# iter:0473 epoch:2836 | align_epoch:0.508
# iter:0473 epoch:2837 | align_epoch:0.495
# iter:0473 epoch:2838 | align_epoch:0.449
# iter:0474 epoch:2839 | align_epoch:0.470
# iter:0474 epoch:2840 | align_epoch:0.486
# iter:0474 epoch:2841 | align_epoch:0.457
# iter:0474 epoch:2842 | align_epoch:0.495
# iter:0474 epoch:2843 | align_epoch:0.496
# iter:0474 epoch:2844 | align_epoch:0.456
# iter:0475 epoch:2845 | align_epoch:0.487
# iter:0475 epoch:2846 | align_epoch:0.517
# iter:0475 epoch:2847 | align_epoch:0.475
# iter:0475 epoch:2848 | align_epoch:0.503
# iter:0475 epoch:2849 | align_epoch:0.492
# iter:0475 epoch:2850 | align_epoch:0.508
# iter:0476 epoch:2851 | align_epoch:0.482
# iter:0476 epoch:2852 | align_epoch:0.478
# iter:0476 epoch:2853 | align_epoch:0.494
# iter:0476 epoch:2854 | align_epoch:0.462
# iter:0476 epoch:2855 | align_epoch:0.481
# iter:0476 epoch:2856 | align_epoch:0.442
# iter:0477 epoch:2857 | align_epoch:0.461
# iter:0477 epoch:2858 | align_epoch:0.508
# iter:0477 epoch:2859 | align_epoch:0.460
# iter:0477 epoch:2860 | align_epoch:0.473
# iter:0477 epoch:2861 | align_epoch:0.509
# iter:0477 epoch:2862 | align_epoch:0.434
# iter:0478 epoch:2863 | align_epoch:0.489
# iter:0478 epoch:2864 | align_epoch:0.477
# iter:0478 epoch:2865 | align_epoch:0.482
# iter:0478 epoch:2866 | align_epoch:0.512
# iter:0478 epoch:2867 | align_epoch:0.491
# iter:0478 epoch:2868 | align_epoch:0.476
# iter:0479 epoch:2869 | align_epoch:0.472
# iter:0479 epoch:2870 | align_epoch:0.483
# iter:0479 epoch:2871 | align_epoch:0.465
# iter:0479 epoch:2872 | align_epoch:0.454
# iter:0479 epoch:2873 | align_epoch:0.502
# iter:0479 epoch:2874 | align_epoch:0.469
# iter:0480 epoch:2875 | align_epoch:0.513
# iter:0480 epoch:2876 | align_epoch:0.456
# iter:0480 epoch:2877 | align_epoch:0.450
# iter:0480 epoch:2878 | align_epoch:0.478
# iter:0480 epoch:2879 | align_epoch:0.483
# iter:0480 epoch:2880 | align_epoch:0.470
# iter:0481 epoch:2881 | align_epoch:0.511
# iter:0481 epoch:2882 | align_epoch:0.488
# iter:0481 epoch:2883 | align_epoch:0.473
# iter:0481 epoch:2884 | align_epoch:0.460
# iter:0481 epoch:2885 | align_epoch:0.477
# iter:0481 epoch:2886 | align_epoch:0.505
# iter:0482 epoch:2887 | align_epoch:0.469
# iter:0482 epoch:2888 | align_epoch:0.484
# iter:0482 epoch:2889 | align_epoch:0.441
# iter:0482 epoch:2890 | align_epoch:0.505
# iter:0482 epoch:2891 | align_epoch:0.479
# iter:0482 epoch:2892 | align_epoch:0.494
# iter:0483 epoch:2893 | align_epoch:0.429
# iter:0483 epoch:2894 | align_epoch:0.476
# iter:0483 epoch:2895 | align_epoch:0.470
# iter:0483 epoch:2896 | align_epoch:0.479
# iter:0483 epoch:2897 | align_epoch:0.483
# iter:0483 epoch:2898 | align_epoch:0.473
# iter:0484 epoch:2899 | align_epoch:0.451
# iter:0484 epoch:2900 | align_epoch:0.514
# iter:0484 epoch:2901 | align_epoch:0.483
# iter:0484 epoch:2902 | align_epoch:0.472
# iter:0484 epoch:2903 | align_epoch:0.495
# iter:0484 epoch:2904 | align_epoch:0.530
# iter:0485 epoch:2905 | align_epoch:0.459
# iter:0485 epoch:2906 | align_epoch:0.497
# iter:0485 epoch:2907 | align_epoch:0.460
# iter:0485 epoch:2908 | align_epoch:0.476
# iter:0485 epoch:2909 | align_epoch:0.501
# iter:0485 epoch:2910 | align_epoch:0.515
# iter:0486 epoch:2911 | align_epoch:0.488
# iter:0486 epoch:2912 | align_epoch:0.503
# iter:0486 epoch:2913 | align_epoch:0.491
# iter:0486 epoch:2914 | align_epoch:0.461
# iter:0486 epoch:2915 | align_epoch:0.477
# iter:0486 epoch:2916 | align_epoch:0.524
# iter:0487 epoch:2917 | align_epoch:0.474
# iter:0487 epoch:2918 | align_epoch:0.476
# iter:0487 epoch:2919 | align_epoch:0.461
# iter:0487 epoch:2920 | align_epoch:0.482
# iter:0487 epoch:2921 | align_epoch:0.485
# iter:0487 epoch:2922 | align_epoch:0.454
# iter:0488 epoch:2923 | align_epoch:0.492
# iter:0488 epoch:2924 | align_epoch:0.498
# iter:0488 epoch:2925 | align_epoch:0.477
# iter:0488 epoch:2926 | align_epoch:0.477
# iter:0488 epoch:2927 | align_epoch:0.521
# iter:0488 epoch:2928 | align_epoch:0.441
# iter:0489 epoch:2929 | align_epoch:0.483
# iter:0489 epoch:2930 | align_epoch:0.506
# iter:0489 epoch:2931 | align_epoch:0.457
# iter:0489 epoch:2932 | align_epoch:0.467
# iter:0489 epoch:2933 | align_epoch:0.487
# iter:0489 epoch:2934 | align_epoch:0.536
# iter:0490 epoch:2935 | align_epoch:0.491
# iter:0490 epoch:2936 | align_epoch:0.491
# iter:0490 epoch:2937 | align_epoch:0.467
# iter:0490 epoch:2938 | align_epoch:0.484
# iter:0490 epoch:2939 | align_epoch:0.480
# iter:0490 epoch:2940 | align_epoch:0.474
# iter:0491 epoch:2941 | align_epoch:0.462
# iter:0491 epoch:2942 | align_epoch:0.484
# iter:0491 epoch:2943 | align_epoch:0.498
# iter:0491 epoch:2944 | align_epoch:0.473
# iter:0491 epoch:2945 | align_epoch:0.474
# iter:0491 epoch:2946 | align_epoch:0.501
# iter:0492 epoch:2947 | align_epoch:0.480
# iter:0492 epoch:2948 | align_epoch:0.470
# iter:0492 epoch:2949 | align_epoch:0.473
# iter:0492 epoch:2950 | align_epoch:0.515
# iter:0492 epoch:2951 | align_epoch:0.445
# iter:0492 epoch:2952 | align_epoch:0.454
# iter:0493 epoch:2953 | align_epoch:0.479
# iter:0493 epoch:2954 | align_epoch:0.485
# iter:0493 epoch:2955 | align_epoch:0.484
# iter:0493 epoch:2956 | align_epoch:0.525
# iter:0493 epoch:2957 | align_epoch:0.472
# iter:0493 epoch:2958 | align_epoch:0.443
# iter:0494 epoch:2959 | align_epoch:0.477
# iter:0494 epoch:2960 | align_epoch:0.487
# iter:0494 epoch:2961 | align_epoch:0.468
# iter:0494 epoch:2962 | align_epoch:0.507
# iter:0494 epoch:2963 | align_epoch:0.495
# iter:0494 epoch:2964 | align_epoch:0.518
# iter:0495 epoch:2965 | align_epoch:0.490
# iter:0495 epoch:2966 | align_epoch:0.481
# iter:0495 epoch:2967 | align_epoch:0.476
# iter:0495 epoch:2968 | align_epoch:0.492
# iter:0495 epoch:2969 | align_epoch:0.476
# iter:0495 epoch:2970 | align_epoch:0.425
# iter:0496 epoch:2971 | align_epoch:0.487
# iter:0496 epoch:2972 | align_epoch:0.488
# iter:0496 epoch:2973 | align_epoch:0.430
# iter:0496 epoch:2974 | align_epoch:0.501
# iter:0496 epoch:2975 | align_epoch:0.499
# iter:0496 epoch:2976 | align_epoch:0.460
# iter:0497 epoch:2977 | align_epoch:0.464
# iter:0497 epoch:2978 | align_epoch:0.495
# iter:0497 epoch:2979 | align_epoch:0.478
# iter:0497 epoch:2980 | align_epoch:0.484
# iter:0497 epoch:2981 | align_epoch:0.497
# iter:0497 epoch:2982 | align_epoch:0.477
# iter:0498 epoch:2983 | align_epoch:0.507
# iter:0498 epoch:2984 | align_epoch:0.516
# iter:0498 epoch:2985 | align_epoch:0.487
# iter:0498 epoch:2986 | align_epoch:0.473
# iter:0498 epoch:2987 | align_epoch:0.480
# iter:0498 epoch:2988 | align_epoch:0.494
# iter:0499 epoch:2989 | align_epoch:0.461
# iter:0499 epoch:2990 | align_epoch:0.476
# iter:0499 epoch:2991 | align_epoch:0.463
# iter:0499 epoch:2992 | align_epoch:0.490
# iter:0499 epoch:2993 | align_epoch:0.501
# iter:0499 epoch:2994 | align_epoch:0.524
# iter:0500 epoch:2995 | align_epoch:0.482
# iter:0500 epoch:2996 | align_epoch:0.486
# iter:0500 epoch:2997 | align_epoch:0.466
# iter:0500 epoch:2998 | align_epoch:0.495
# iter:0500 epoch:2999 | align_epoch:0.472
# iter:0500 epoch:3000 | align_epoch:0.472
# iter:0501 epoch:3001 | align_epoch:0.489
# iter:0501 epoch:3002 | align_epoch:0.517
# iter:0501 epoch:3003 | align_epoch:0.483
# iter:0501 epoch:3004 | align_epoch:0.472
# iter:0501 epoch:3005 | align_epoch:0.480
# iter:0501 epoch:3006 | align_epoch:0.513
# iter:0502 epoch:3007 | align_epoch:0.511
# iter:0502 epoch:3008 | align_epoch:0.470
# iter:0502 epoch:3009 | align_epoch:0.464
# iter:0502 epoch:3010 | align_epoch:0.485
# iter:0502 epoch:3011 | align_epoch:0.469
# iter:0502 epoch:3012 | align_epoch:0.475
# iter:0503 epoch:3013 | align_epoch:0.454
# iter:0503 epoch:3014 | align_epoch:0.487
# iter:0503 epoch:3015 | align_epoch:0.483
# iter:0503 epoch:3016 | align_epoch:0.496
# iter:0503 epoch:3017 | align_epoch:0.468
# iter:0503 epoch:3018 | align_epoch:0.477
# iter:0504 epoch:3019 | align_epoch:0.463
# iter:0504 epoch:3020 | align_epoch:0.515
# iter:0504 epoch:3021 | align_epoch:0.463
# iter:0504 epoch:3022 | align_epoch:0.464
# iter:0504 epoch:3023 | align_epoch:0.499
# iter:0504 epoch:3024 | align_epoch:0.466
# iter:0505 epoch:3025 | align_epoch:0.474
# iter:0505 epoch:3026 | align_epoch:0.506
# iter:0505 epoch:3027 | align_epoch:0.495
# iter:0505 epoch:3028 | align_epoch:0.492
# iter:0505 epoch:3029 | align_epoch:0.473
# iter:0505 epoch:3030 | align_epoch:0.468
# iter:0506 epoch:3031 | align_epoch:0.470
# iter:0506 epoch:3032 | align_epoch:0.486
# iter:0506 epoch:3033 | align_epoch:0.469
# iter:0506 epoch:3034 | align_epoch:0.466
# iter:0506 epoch:3035 | align_epoch:0.495
# iter:0506 epoch:3036 | align_epoch:0.465
# iter:0507 epoch:3037 | align_epoch:0.487
# iter:0507 epoch:3038 | align_epoch:0.478
# iter:0507 epoch:3039 | align_epoch:0.483
# iter:0507 epoch:3040 | align_epoch:0.476
# iter:0507 epoch:3041 | align_epoch:0.493
# iter:0507 epoch:3042 | align_epoch:0.488
# iter:0508 epoch:3043 | align_epoch:0.483
# iter:0508 epoch:3044 | align_epoch:0.493
# iter:0508 epoch:3045 | align_epoch:0.479
# iter:0508 epoch:3046 | align_epoch:0.491
# iter:0508 epoch:3047 | align_epoch:0.462
# iter:0508 epoch:3048 | align_epoch:0.466
# iter:0509 epoch:3049 | align_epoch:0.491
# iter:0509 epoch:3050 | align_epoch:0.484
# iter:0509 epoch:3051 | align_epoch:0.460
# iter:0509 epoch:3052 | align_epoch:0.496
# iter:0509 epoch:3053 | align_epoch:0.476
# iter:0509 epoch:3054 | align_epoch:0.523
# iter:0510 epoch:3055 | align_epoch:0.499
# iter:0510 epoch:3056 | align_epoch:0.475
# iter:0510 epoch:3057 | align_epoch:0.487
# iter:0510 epoch:3058 | align_epoch:0.522
# iter:0510 epoch:3059 | align_epoch:0.477
# iter:0510 epoch:3060 | align_epoch:0.468
# iter:0511 epoch:3061 | align_epoch:0.469
# iter:0511 epoch:3062 | align_epoch:0.487
# iter:0511 epoch:3063 | align_epoch:0.487
# iter:0511 epoch:3064 | align_epoch:0.478
# iter:0511 epoch:3065 | align_epoch:0.497
# iter:0511 epoch:3066 | align_epoch:0.437
# iter:0512 epoch:3067 | align_epoch:0.494
# iter:0512 epoch:3068 | align_epoch:0.483
# iter:0512 epoch:3069 | align_epoch:0.496
# iter:0512 epoch:3070 | align_epoch:0.440
# iter:0512 epoch:3071 | align_epoch:0.499
# iter:0512 epoch:3072 | align_epoch:0.478
# iter:0513 epoch:3073 | align_epoch:0.479
# iter:0513 epoch:3074 | align_epoch:0.482
# iter:0513 epoch:3075 | align_epoch:0.484
# iter:0513 epoch:3076 | align_epoch:0.484
# iter:0513 epoch:3077 | align_epoch:0.485
# iter:0513 epoch:3078 | align_epoch:0.520
# iter:0514 epoch:3079 | align_epoch:0.497
# iter:0514 epoch:3080 | align_epoch:0.487
# iter:0514 epoch:3081 | align_epoch:0.468
# iter:0514 epoch:3082 | align_epoch:0.509
# iter:0514 epoch:3083 | align_epoch:0.480
# iter:0514 epoch:3084 | align_epoch:0.507
# iter:0515 epoch:3085 | align_epoch:0.478
# iter:0515 epoch:3086 | align_epoch:0.500
# iter:0515 epoch:3087 | align_epoch:0.470
# iter:0515 epoch:3088 | align_epoch:0.500
# iter:0515 epoch:3089 | align_epoch:0.506
# iter:0515 epoch:3090 | align_epoch:0.432
# iter:0516 epoch:3091 | align_epoch:0.501
# iter:0516 epoch:3092 | align_epoch:0.498
# iter:0516 epoch:3093 | align_epoch:0.479
# iter:0516 epoch:3094 | align_epoch:0.531
# iter:0516 epoch:3095 | align_epoch:0.473
# iter:0516 epoch:3096 | align_epoch:0.450
# iter:0517 epoch:3097 | align_epoch:0.493
# iter:0517 epoch:3098 | align_epoch:0.488
# iter:0517 epoch:3099 | align_epoch:0.472
# iter:0517 epoch:3100 | align_epoch:0.486
# iter:0517 epoch:3101 | align_epoch:0.471
# iter:0517 epoch:3102 | align_epoch:0.462
# iter:0518 epoch:3103 | align_epoch:0.470
# iter:0518 epoch:3104 | align_epoch:0.485
# iter:0518 epoch:3105 | align_epoch:0.487
# iter:0518 epoch:3106 | align_epoch:0.488
# iter:0518 epoch:3107 | align_epoch:0.467
# iter:0518 epoch:3108 | align_epoch:0.522
# iter:0519 epoch:3109 | align_epoch:0.476
# iter:0519 epoch:3110 | align_epoch:0.501
# iter:0519 epoch:3111 | align_epoch:0.501
# iter:0519 epoch:3112 | align_epoch:0.471
# iter:0519 epoch:3113 | align_epoch:0.463
# iter:0519 epoch:3114 | align_epoch:0.459
# iter:0520 epoch:3115 | align_epoch:0.506
# iter:0520 epoch:3116 | align_epoch:0.530
# iter:0520 epoch:3117 | align_epoch:0.499
# iter:0520 epoch:3118 | align_epoch:0.475
# iter:0520 epoch:3119 | align_epoch:0.460
# iter:0520 epoch:3120 | align_epoch:0.440

# %% [markdown]
# ## Test the LENet

# %%
model.eval()
with torch.no_grad():
    Z = model(X)
    Y = LENet( Z, A, beta, K = 32 )

Z = Z.cpu()
Y = Y.cpu()
Y_norm = normalize(Y)

Z_train = Z[data.train_mask]
Z_test = Z[data.test_mask]
Y_train = Y[data.train_mask]
Y_test = Y[data.test_mask]
Y_norm_train = Y_norm[data.train_mask]
Y_norm_test = Y_norm[data.test_mask]

y_train = y[data.train_mask]
y_test = y[data.test_mask]

clf = LogisticRegression()
clf.fit( Z_train, y_train )
acc_Z = clf.score( Z_test, y_test )

clf = LogisticRegression()
clf.fit( Y_train, y_train )
acc_Y = clf.score( Y_test, y_test )

clf = LogisticRegression()
clf.fit( Y_norm_train, y_train )
acc_Y_norm = clf.score( Y_norm_test, y_test )

# %%
acc_Z, acc_Y, acc_Y_norm
# Out:
# (0.771, 0.837, 0.833)

# %% [markdown]
# ### Parameter setting tip
#
# Since we train the linear encoder to minimize objective function $\| Z - Y\|_F$, to reach a reasonable result, it is recommended to tune the parameter $\beta$ (so $\alpha$) such that $\|Y\|_F \approx \| Z\|_F = m$. In cora dataset case, $m = 2708$.

# %%
np.power( np.linalg.norm(Y, 'fro'), 2 )
# Out:
# 2917.572767555961

# %% [markdown]
# ## Visualizing result

# %%
Y_tsne = TSNE(
            n_components=2,
            perplexity=100,
            init="pca",
            random_state=42,
            ).fit_transform( Y )
# Out:
# d:\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# d:\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
def symmetric_normalize(A):
    # normalize a symmeteric adjacency matrix
    row_sum = A.sum(axis=1)
    row_sum = (row_sum==0)*1 + row_sum
    D_inv_21 = sp.csr_array( sp.diags( np.power(row_sum, -0.5) ) )
    A_sym = D_inv_21 @ A @ D_inv_21
    return A_sym

A_plot = sp.coo_matrix( (np.ones_like(data.edge_index[0]), (data.edge_index[0], data.edge_index[1])), shape=(data.num_nodes, data.num_nodes) )

A_plot = sp.csr_array(A_plot)
# Symmetry: A := A + (AT-A)[AT>A]
A_plot =  A_plot + (A_plot.T - A_plot) * (A_plot.T > A_plot)

# %%
def plot_scatter_with_edge(ax, Z, fig_paras, A):
    def plot_graph_edges(A):
        indptr = A.indptr
        indices = A.indices
        repeat_num = indptr[1:] - indptr[:-1]
        edge_begin = np.repeat(Z, repeat_num, axis = 0)
        edge_over = np.vstack( [ Z[indices[indptr[i]:indptr[i+1]]] for i in range(m) ] )
        x,y = edge_begin[:, 0], edge_begin[:, 1]
        u,v = edge_over[:, 0]-x, edge_over[:, 1]-y
        ax.quiver(x,y, u,v, color='k', lw=0.1, alpha=0.1, angles='xy', scale_units='xy', scale=1)
    plot_graph_edges(A)
    ax.scatter(Z[:, 0], Z[:, 1], **fig_paras, edgecolors='k', lw=2, zorder=1,s=22)
    ax.scatter(Z[:, 0], Z[:, 1], **fig_paras, zorder=1, s=20)



colors = np.asarray( ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9'] )
fig_paras = {
            'c': colors[y],
            # 'edgecolors': 'gray',
            # 'lw': 0.05,
            'alpha': 1,
            # 's': 20, 
}
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
fig, ax = plt.subplots(figsize=(6, 5))
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xticks([])
ax.set_yticks([])
plot_scatter_with_edge(ax, Y_tsne, fig_paras, A_plot)
fig.tight_layout()

# %% [markdown]
# Plot heatmap

# %%
X_norm = normalize(X.cpu())

X_s = np.vstack( [ X_norm[y==j] for j in range(7) ] )
Y_s = np.vstack( [ Y_norm[y==j] for j in range(7) ] )

sim_X = np.abs(X_s @ X_s.T)
sim_Y = np.abs(Y_s @ Y_s.T)

# %%
def plot_heatmap(fig, ax, sim, cmap):
    im = ax.imshow(sim, cmap=cmap, origin='upper')
    ax.xaxis.tick_top()
    ax.set_box_aspect(1)
    fig.colorbar(im)

cmap = 'Blues'
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
fig_X, ax_X = plt.subplots(figsize=(6, 5))
fig_Z, ax_Z = plt.subplots(figsize=(6, 5))
plot_heatmap(fig_X, ax_X, sim_X, cmap)
plot_heatmap(fig_Z, ax_Z, sim_Y, cmap)
fig_X.tight_layout()
fig_Z.tight_layout()

# %% [markdown]
# plot align function

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
fontsize = 15
color_origin = 'tab:blue'

fig, ax = plt.subplots(figsize=(7,5))
ax.set_xlabel('训练批次数', fontproperties="SimSun", fontsize=fontsize)
ax.set_ylabel('目标函数值', fontproperties="SimSun", color='k', fontsize=fontsize)
# ax.tick_params(axis='y', labelcolor=color_origin)
ax.plot(align_epoch, label='loss', color=color_origin)
